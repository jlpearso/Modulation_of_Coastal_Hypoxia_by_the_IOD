# %% [markdown]
# # Setup

# %%
# import your standard packages
# %run pkgs.py

# import your local functions
sys.path.insert(1, '../')
from local_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline
# Out:
# Default libraries loaded.

# %% [markdown]
# # Paths and Parameters

# %%
bounds_AS = [68,79,3,20]
bounds_wBoB = [79,87,2,21]
bounds_nwBoB = [79,87,15,21]
bounds_swBoB = [79,87,2,15]
bounds_BoB = [87,100,0,23]

hyp_thresh = 61

# %% [markdown]
# # Get Data

# %%
# AWG
ds_WOD = xr.open_dataset('../data/wod_processed.nc')
ds_WOD
# Out:
# <xarray.Dataset>
# Dimensions:                      (coastal_loc: 341437, coastal_pos: 139423, lonmin,lonmax,latmin,latmax: 4, pres: 57, time: 341437)
# Coordinates:
#   * time                         (time) datetime64[ns] 1770-01-01 ... 2020-05-31
#   * pres                         (pres) int64 0 5 10 15 ... 1350 1400 1450 1500
#   * coastal_loc                  (coastal_loc) int64 0 1 2 ... 341435 341436
#   * coastal_pos                  (coastal_pos) int64 0 1 2 ... 139421 139422
#   * lonmin,lonmax,latmin,latmax  (lonmin,lonmax,latmin,latmax) int64 0 1 2 3
# Data variables:
#     temp                         (time, pres) float64 ...
#     sal                          (time, pres) float64 ...
#     doxy                         (time, pres) float64 ...
#     nitrate                      (time, pres) float64 ...
#     phosphate                    (time, pres) float64 ...
#     lat                          (time) float32 ...
#     lon                          (time) float32 ...
#     cast_id                      (time) object ...
#     temp_40_200                  (time) float64 ...
#     doxy_40_200                  (time) float64 ...
#     sal_40_200                   (time) float64 ...
#     nitrate_40_200               (time) float64 ...
#     phosphate_40_200             (time) float64 ...
#     temp_50_200                  (time) float64 ...
#     doxy_50_200                  (time) float64 ...
#     sal_50_200                   (time) float64 ...
#     nitrate_50_200               (time) float64 ...
#     phosphate_50_200             (time) float64 ...
#     temp_50_225                  (time) float64 ...
#     doxy_50_225                  (time) float64 ...
#     sal_50_225                   (time) float64 ...
#     nitrate_50_225               (time) float64 ...
#     phosphate_50_225             (time) float64 ...
#     coastal_mask                 (coastal_loc) bool ...
#     coastal_mask_xx              (coastal_pos) float32 ...
#     coastal_mask_yy              (coastal_pos) float32 ...
#     coastal_mask_bounds          (lonmin,lonmax,latmin,latmax) float64 ...

# %% [markdown]
# # Subset

# %%
#----------------- Arabian Sea ---------------------#

ind_AS = (ds_WOD.lon < bounds_AS[1]) & (ds_WOD.lon > bounds_AS[0]) & (ds_WOD.lat < bounds_AS[3]) & (ds_WOD.lat > bounds_AS[2]) 

#subset gridded data
temp_AS = ds_WOD.temp_50_200[ind_AS]
doxy_AS = ds_WOD.doxy_50_200[ind_AS]
# nitrate_AS = ds_WOD.nitrate_50_200[ind_AS]
lat_AS = ds_WOD.lat[ind_AS]
lon_AS = ds_WOD.lon[ind_AS]
time_AS = ds_WOD.time[ind_AS]
mon_AS = time_AS.dt.month
    
# convert to coastal
mask_AS = mask_coast(np.array(lon_AS),np.array(lat_AS),np.array(ds_WOD.coastal_mask_bounds))
temp_AS = temp_AS[mask_AS]
doxy_AS = doxy_AS[mask_AS]
# nitrate_AS = nitrate_AS[mask_AS]
lat_AS = lat_AS[mask_AS]
lon_AS = lon_AS[mask_AS]
time_AS = time_AS[mask_AS]
mon_AS = mon_AS[mask_AS]

#----------------- NW BoB ---------------------#
ind_nwBoB = (ds_WOD.lon < bounds_nwBoB[1]) & (ds_WOD.lon > bounds_nwBoB[0]) & (ds_WOD.lat < bounds_nwBoB[3]) & (ds_WOD.lat > bounds_nwBoB[2]) 

#subset gridded data
temp_nwBoB = ds_WOD.temp_50_200[ind_nwBoB]
doxy_nwBoB = ds_WOD.doxy_50_200[ind_nwBoB]
# nitrate_nwBoB = ds_WOD.nitrate_50_200[ind_nwBoB]
lat_nwBoB = ds_WOD.lat[ind_nwBoB]
lon_nwBoB = ds_WOD.lon[ind_nwBoB]
time_nwBoB = ds_WOD.time[ind_nwBoB]
mon_nwBoB = time_nwBoB.dt.month
    
# convert to coastal
mask_nwBoB = mask_coast(np.array(lon_nwBoB),np.array(lat_nwBoB),np.array(ds_WOD.coastal_mask_bounds))
temp_nwBoB = temp_nwBoB[mask_nwBoB]
doxy_nwBoB = doxy_nwBoB[mask_nwBoB]
# nitrate_nwBoB = nitrate_nwBoB[mask_nwBoB]
lat_nwBoB = lat_nwBoB[mask_nwBoB]
lon_nwBoB = lon_nwBoB[mask_nwBoB]
time_nwBoB = time_nwBoB[mask_nwBoB]
mon_nwBoB = mon_nwBoB[mask_nwBoB]

#----------------- SW BoB ---------------------#
ind_swBoB = (ds_WOD.lon < bounds_swBoB[1]) & (ds_WOD.lon > bounds_swBoB[0]) & (ds_WOD.lat < bounds_swBoB[3]) & (ds_WOD.lat > bounds_swBoB[2]) 

#subset gridded data
temp_swBoB = ds_WOD.temp_50_200[ind_swBoB]
doxy_swBoB = ds_WOD.doxy_50_200[ind_swBoB]
# nitrate_swBoB = ds_WOD.nitrate_50_200[ind_swBoB]
lat_swBoB = ds_WOD.lat[ind_swBoB]
lon_swBoB = ds_WOD.lon[ind_swBoB]
time_swBoB = ds_WOD.time[ind_swBoB]
mon_swBoB = time_swBoB.dt.month
    
# convert to coastal
mask_swBoB = mask_coast(np.array(lon_swBoB),np.array(lat_swBoB),np.array(ds_WOD.coastal_mask_bounds))
temp_swBoB = temp_swBoB[mask_swBoB]
doxy_swBoB = doxy_swBoB[mask_swBoB]
# nitrate_swBoB = nitrate_swBoB[mask_swBoB]
lat_swBoB = lat_swBoB[mask_swBoB]
lon_swBoB = lon_swBoB[mask_swBoB]
time_swBoB = time_swBoB[mask_swBoB]
mon_swBoB = mon_swBoB[mask_swBoB]

#---------------- Western Bay of Bengal --------------------#

ind_wBoB = (ds_WOD.lon < bounds_wBoB[1]) & (ds_WOD.lon > bounds_wBoB[0]) & (ds_WOD.lat < bounds_wBoB[3]) & (ds_WOD.lat > bounds_wBoB[2]) 

#subset gridded data
temp_wBoB = ds_WOD.temp_50_200[ind_wBoB]
doxy_wBoB = ds_WOD.doxy_50_200[ind_wBoB]
# nitrate_wBoB = ds_WOD.nitrate_50_200[ind_wBoB]
lat_wBoB = ds_WOD.lat[ind_wBoB]
lon_wBoB = ds_WOD.lon[ind_wBoB]
time_wBoB = ds_WOD.time[ind_wBoB]
mon_wBoB = time_wBoB.dt.month
    
# convert to coastal
mask_wBoB = mask_coast(np.array(lon_wBoB),np.array(lat_wBoB),np.array(ds_WOD.coastal_mask_bounds))
temp_wBoB = temp_wBoB[mask_wBoB]
doxy_wBoB = doxy_wBoB[mask_wBoB]
# nitrate_wBoB = nitrate_wBoB[mask_wBoB]
lat_wBoB = lat_wBoB[mask_wBoB]
lon_wBoB = lon_wBoB[mask_wBoB]
time_wBoB = time_wBoB[mask_wBoB]
mon_wBoB = mon_wBoB[mask_wBoB]

#---------------- Bay of Bengal --------------------#

ind_BoB = (ds_WOD.lon < bounds_BoB[1]) & (ds_WOD.lon > bounds_BoB[0]) & (ds_WOD.lat < bounds_BoB[3]) & (ds_WOD.lat > bounds_BoB[2]) 

#subset gridded data
temp_BoB = ds_WOD.temp_50_200[ind_BoB]
doxy_BoB = ds_WOD.doxy_50_200[ind_BoB]
# nitrate_BoB = ds_WOD.nitrate_50_200[ind_BoB]
lat_BoB = ds_WOD.lat[ind_BoB]
lon_BoB = ds_WOD.lon[ind_BoB]
time_BoB = ds_WOD.time[ind_BoB]
mon_BoB = time_BoB.dt.month

# convert to coastal
mask_BoB = mask_coast(np.array(lon_BoB),np.array(lat_BoB),np.array(ds_WOD.coastal_mask_bounds))
temp_BoB = temp_BoB[mask_BoB]
doxy_BoB = doxy_BoB[mask_BoB]
# nitrate_BoB = nitrate_BoB[mask_BoB]
lat_BoB = lat_BoB[mask_BoB]
lon_BoB = lon_BoB[mask_BoB]
time_BoB = time_BoB[mask_BoB]
mon_BoB = mon_BoB[mask_BoB]

# %%
# # make a scatter plot with rectangles to outline different locations...don't need in the figure necessairly.

    
# cmin = -0.2
# cmax = 0.2
# levels = np.linspace(cmin, cmax, 10)

# # Start figure
# fig = plt.figure(figsize=(6, 4), dpi = 200)
# ax = plt.axes(projection=ccrs.PlateCarree())
# add_land(ax, [55,100,0,23])
# p =plt.scatter(lon_AS[~np.isnan(doxy_AS)],lat_AS[~np.isnan(doxy_AS)],
#             s = 20,c='k',marker = '.')
# p =plt.scatter(lon_nwBoB[~np.isnan(doxy_nwBoB)],lat_nwBoB[~np.isnan(doxy_nwBoB)],
#             s = 20,c='g',marker = '.')
# p =plt.scatter(lon_swBoB[~np.isnan(doxy_swBoB)],lat_swBoB[~np.isnan(doxy_swBoB)],
#             s = 20,c='r',marker = '.')
# p =plt.scatter(lon_BoB[~np.isnan(doxy_BoB)],lat_BoB[~np.isnan(doxy_BoB)],
#             s = 20,c='k',marker = '.')
# plt.title('Profile Locations')

# %%
# group AS into IOD years

# load DMI data
ds_DMI= xr.open_dataset('../data/dmi_processed.nc')
ds_DMI

posIODyears = list(np.array(ds_DMI.pos_IOD_years))
negIODyears = list(np.array(ds_DMI.neg_IOD_years))
neuIODyears = list(np.array(ds_DMI.neu_IOD_years)) 

# groupd into IOD years

IODyear_begin = '-06-01' # month-day of IOD year
IODyear_end = '-05-31' # month-day of year AFTER IOD year

# %%
# Arabian Sea

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_AS,posIODlat_AS,posIODlon_AS,posIODtime_AS,posIODmon_AS,posIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_AS,negIODlat_AS,negIODlon_AS,negIODtime_AS,negIODmon_AS,negIODseas_AS= IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_AS,neuIODlat_AS,neuIODlon_AS,neuIODtime_AS,neuIODmon_AS,neuIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,neuIODyears)



# nwBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_nwBoB,posIODlat_nwBoB,posIODlon_nwBoB,posIODtime_nwBoB,posIODmon_nwBoB,posIODseas_nwBoB = IOD_year_group(doxy_nwBoB,
                                             lat_nwBoB,lon_nwBoB,time_nwBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_nwBoB,negIODlat_nwBoB,negIODlon_nwBoB,negIODtime_nwBoB,negIODmon_nwBoB,negIODseas_nwBoB = IOD_year_group(doxy_nwBoB,
                                             lat_nwBoB,lon_nwBoB,time_nwBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_nwBoB,neuIODlat_nwBoB,neuIODlon_nwBoB,neuIODtime_nwBoB,neuIODmon_nwBoB,neuIODseas_nwBoB = IOD_year_group(doxy_nwBoB,
                                             lat_nwBoB,lon_nwBoB,time_nwBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)





# wBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_swBoB,posIODlat_swBoB,posIODlon_swBoB,posIODtime_swBoB,posIODmon_swBoB,posIODseas_swBoB = IOD_year_group(doxy_swBoB,
                                             lat_swBoB,lon_swBoB,time_swBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_swBoB,negIODlat_swBoB,negIODlon_swBoB,negIODtime_swBoB,negIODmon_swBoB,negIODseas_swBoB = IOD_year_group(doxy_swBoB,
                                             lat_swBoB,lon_swBoB,time_swBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_swBoB,neuIODlat_swBoB,neuIODlon_swBoB,neuIODtime_swBoB,neuIODmon_swBoB,neuIODseas_swBoB = IOD_year_group(doxy_swBoB,
                                             lat_swBoB,lon_swBoB,time_swBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)





# wBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_wBoB,posIODlat_wBoB,posIODlon_wBoB,posIODtime_wBoB,posIODmon_wBoB,posIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_wBoB,negIODlat_wBoB,negIODlon_wBoB,negIODtime_wBoB,negIODmon_wBoB,negIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_wBoB,neuIODlat_wBoB,neuIODlon_wBoB,neuIODtime_wBoB,neuIODmon_wBoB,neuIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)




# eBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_BoB,posIODlat_BoB,posIODlon_BoB,posIODtime_BoB,posIODmon_BoB,posIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_BoB,negIODlat_BoB,negIODlon_BoB,negIODtime_BoB,negIODmon_BoB,negIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_BoB,neuIODlat_BoB,neuIODlon_BoB,neuIODtime_BoB,neuIODmon_BoB,neuIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,neuIODyears)

# %% [markdown]
# # Histograms and K-S test
#
# Ks Test Sources
# https://abhyankar-ameya.medium.com/kolmogorov-smirnov-two-sample-test-with-python-70c309107c78
#
# http://www.stats.ox.ac.uk/~massa/Lecture%2013.pdf
#
# https://stackoverflow.com/questions/10884668/two-sample-kolmogorov-smirnov-test-in-python-scipy
#
# https://math.stackexchange.com/questions/1251401/kolmogorov-smirnov-two-sample-test
#
# http://www.stat.yale.edu/Courses/1997-98/101/sigtest.htm
#
# not exactly python but helpul
#
# https://www.graphpad.com/guides/prism/8/statistics/interpreting_results_kolmogorov-smirnov_test.htm

# %%
# Make Histograms 
binedges = np.linspace(0,250,12)
names = ['Positive IOD Years','Negative IOD Years','All Observed Years']
# title = ['Eastern Arabian Sea', 'Western Bay of Bengal','Eastern Bay of Bengal']
title = ['SEAS', 'WBoB','EBoB']
# colors = ['teal','orange','purple']
colors = ['#003466','#C47900']
letters = ['a','b','c','d','e','f']

fig = plt.figure(figsize=(10, 4), dpi=400)

params = {'legend.fontsize': 10,
         'axes.labelsize': 11,
         'axes.titlesize': 12,
         'xtick.labelsize':10,
         'ytick.labelsize':10}

pylab.rcParams.update(params)

#########################

data_AS = [posIODdata_AS,negIODdata_AS,doxy_AS]
data_wBoB = [posIODdata_wBoB,negIODdata_wBoB,doxy_wBoB]
data_BoB = [posIODdata_BoB,negIODdata_BoB,doxy_BoB]
time_data_AS = [posIODmon_AS,negIODmon_AS,mon_AS]
time_data_wBoB = [posIODmon_wBoB,negIODmon_wBoB,mon_wBoB]
time_data_BoB = [posIODmon_BoB,negIODmon_BoB,mon_BoB]

cnt = 1
for pp in range(3):

    if pp==0:
        pdata = data_AS[0]
        ndata = data_AS[1]
        alldata = data_AS[2]
        
        ptdata = time_data_AS[0]
        ntdata = time_data_AS[1]
        alltdata = time_data_AS[2]
        
    elif pp==1:
        pdata = data_wBoB[0]
        ndata = data_wBoB[1]
        alldata = data_wBoB[2]
        
        ptdata = time_data_wBoB[0]
        ntdata = time_data_wBoB[1]
        alltdata = time_data_wBoB[2]
        
    else:
        pdata = data_BoB[0]
        ndata = data_BoB[1]
        alldata = data_BoB[2]
        
        ptdata = time_data_BoB[0]
        ntdata = time_data_BoB[1]
        alltdata = time_data_BoB[2]

    # O2
    x1 = pdata[~np.isnan(pdata)]
    x2 = ndata[~np.isnan(ndata)]
    x3 = alldata[~np.isnan(alldata)]

    x1t = ptdata[~np.isnan(pdata)]
    x2t = ntdata[~np.isnan(ndata)]
    x3t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    # ks test

    pos_neg_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    pos_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    neg_all_ks_sf = stats.ks_2samp(x2_sf,x3_sf)

    pos_neg_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    pos_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    neg_all_ks_ws = stats.ks_2samp(x2_ws,x3_ws)

    # weights for relative frequency
    
    weights_sf = [np.zeros_like(x1_sf) + 1./len(x1_sf),
              np.zeros_like(x2_sf) + 1./len(x2_sf),
              np.zeros_like(x3_sf) + 1./len(x3_sf)]

    weights_ws = [np.zeros_like(x1_ws) + 1./len(x1_ws),
              np.zeros_like(x2_ws) + 1./len(x2_ws),
              np.zeros_like(x3_ws) + 1./len(x3_ws)]

    #subplot summer fall
    ax = fig.add_subplot(2,3,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')

    plt.hist(x1_sf,bins = binedges, weights=weights_sf[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_sf,bins = binedges, weights=weights_sf[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_title(title[pp])
    
    if cnt == 1:
        ax.set_ylabel('Summer/Fall \nRelative Frequency')
        
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.92, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_sf[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_sf[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_sf)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_sf)), x = 0.6,y=0.83, fontsize = 8)
    
    # subplot winter spring
    ax = fig.add_subplot(2,3,cnt + 3)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia')
    plt.hist(x1_ws,bins = binedges, weights=weights_ws[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_ws,bins = binedges, weights=weights_ws[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_xlabel('50-200dbar [$O_2$] ($\mu mol/ kg$)')
    if cnt == 1:
        ax.set_ylabel('Winter/Spring \nRelative Frequency')
        
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.92, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_ws[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_ws[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_ws)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_ws)), x = 0.6,y=0.83, fontsize = 8)
    
    cnt += 1

ax.legend(loc='lower center', bbox_to_anchor=(-.75, -.6),
          ncol=3, fancybox=True)

# %%
# Make Histograms 
binedges = np.linspace(0,250,12)
names = ['Positive IOD Years','Negative IOD Years','All Observed Years']
# title = ['Eastern Arabian Sea', 'Western Bay of Bengal','Eastern Bay of Bengal']
title = ['EAS', 'SWBoB','NWBoB','EBoB']
# colors = ['teal','orange','purple']
colors = ['#003466','#C47900']
letters = ['a','b','c','d','e','f','g','h','i','j','k']

fig = plt.figure(figsize=(10, 5), dpi=400)

params = {'legend.fontsize': 10,
         'axes.labelsize': 9,
         'axes.titlesize': 10,
         'xtick.labelsize':10,
         'ytick.labelsize':10}

pylab.rcParams.update(params)

#########################

data_AS = [posIODdata_AS,negIODdata_AS,doxy_AS]
data_wBoB = [posIODdata_wBoB,negIODdata_wBoB,doxy_wBoB]
data_nwBoB = [posIODdata_nwBoB,negIODdata_nwBoB,doxy_nwBoB]
data_swBoB = [posIODdata_swBoB,negIODdata_swBoB,doxy_swBoB]
data_BoB = [posIODdata_BoB,negIODdata_BoB,doxy_BoB]
time_data_AS = [posIODmon_AS,negIODmon_AS,mon_AS]
time_data_wBoB = [posIODmon_wBoB,negIODmon_wBoB,mon_wBoB]
time_data_nwBoB = [posIODmon_nwBoB,negIODmon_nwBoB,mon_nwBoB]
time_data_swBoB = [posIODmon_swBoB,negIODmon_swBoB,mon_swBoB]
time_data_BoB = [posIODmon_BoB,negIODmon_BoB,mon_BoB]

cnt = 1
for pp in range(4):

    if pp==0:
        pdata = data_AS[0]
        ndata = data_AS[1]
        alldata = data_AS[2]
        
        ptdata = time_data_AS[0]
        ntdata = time_data_AS[1]
        alltdata = time_data_AS[2]
        
    elif pp==1:
        pdata = data_swBoB[0]
        ndata = data_swBoB[1]
        alldata = data_swBoB[2]
        
        ptdata = time_data_swBoB[0]
        ntdata = time_data_swBoB[1]
        alltdata = time_data_swBoB[2]
        
    elif pp==2:
        pdata = data_nwBoB[0]
        ndata = data_nwBoB[1]
        alldata = data_nwBoB[2]
        
        ptdata = time_data_nwBoB[0]
        ntdata = time_data_nwBoB[1]
        alltdata = time_data_nwBoB[2]
        
    else:
        pdata = data_BoB[0]
        ndata = data_BoB[1]
        alldata = data_BoB[2]
        
        ptdata = time_data_BoB[0]
        ntdata = time_data_BoB[1]
        alltdata = time_data_BoB[2]

    # O2
    x1 = pdata[~np.isnan(pdata)]
    x2 = ndata[~np.isnan(ndata)]
    x3 = alldata[~np.isnan(alldata)]

    x1t = ptdata[~np.isnan(pdata)]
    x2t = ntdata[~np.isnan(ndata)]
    x3t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]

    # ks test

    pos_neg_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    pos_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    neg_all_ks_sf = stats.ks_2samp(x2_sf,x3_sf)

    pos_neg_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    pos_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    neg_all_ks_ws = stats.ks_2samp(x2_ws,x3_ws)

    # weights for relative frequency
    
    weights_sf = [np.zeros_like(x1_sf) + 1./len(x1_sf),
              np.zeros_like(x2_sf) + 1./len(x2_sf),
              np.zeros_like(x3_sf) + 1./len(x3_sf)]

    weights_ws = [np.zeros_like(x1_ws) + 1./len(x1_ws),
              np.zeros_like(x2_ws) + 1./len(x2_ws),
              np.zeros_like(x3_ws) + 1./len(x3_ws)]

    #subplot summer fall
    ax = fig.add_subplot(2,4,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')
    plt.hist(x1_sf,bins = binedges, weights=weights_sf[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_sf,bins = binedges, weights=weights_sf[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'lightgray', linestyle = ':')
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_title(title[pp])
    
    if cnt == 1:
        ax.set_ylabel('Summer/Fall \nRelative Frequency')
        
    add_letter(ax, letters[cnt-1], x = 0.01, y=0.94, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_sf[0],4)), x = 0.46,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_sf[1],4)), x = 0.46,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_sf)), x = 0.46,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_sf)), x = 0.46,y=0.83, fontsize = 8)
    
    # subplot winter spring
    ax = fig.add_subplot(2,4,cnt + 4)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia')
    plt.hist(x1_ws,bins = binedges, weights=weights_ws[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_ws,bins = binedges, weights=weights_ws[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'lightgray', linestyle = ':')
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_xlabel('50-200dbar [$O_2$] ($\mu mol/ kg$)')
    if cnt == 1:
        ax.set_ylabel('Winter/Spring \nRelative Frequency')
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.94, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_ws[0],4)), x = 0.46,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_ws[1],4)), x = 0.46,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_ws)), x = 0.46,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_ws)), x = 0.46,y=0.83, fontsize = 8)
    
    cnt += 1

ax.legend(loc='lower center', bbox_to_anchor=(-1.4, -.6),
          ncol=3, fancybox=True)

# %% [markdown]
# # Repeat for 40-200

# %%
#----------------- Arabian Sea ---------------------#

ind_AS = (ds_WOD.lon < bounds_AS[1]) & (ds_WOD.lon > bounds_AS[0]) & (ds_WOD.lat < bounds_AS[3]) & (ds_WOD.lat > bounds_AS[2]) 

#subset gridded data
temp_AS = ds_WOD.temp_40_200[ind_AS]
doxy_AS = ds_WOD.doxy_40_200[ind_AS]
# nitrate_AS = ds_WOD.nitrate_40_200[ind_AS]
lat_AS = ds_WOD.lat[ind_AS]
lon_AS = ds_WOD.lon[ind_AS]
time_AS = ds_WOD.time[ind_AS]
mon_AS = time_AS.dt.month
    
# convert to coastal
mask_AS = mask_coast(np.array(lon_AS),np.array(lat_AS),np.array(ds_WOD.coastal_mask_bounds))
temp_AS = temp_AS[mask_AS]
doxy_AS = doxy_AS[mask_AS]
# nitrate_AS = nitrate_AS[mask_AS]
lat_AS = lat_AS[mask_AS]
lon_AS = lon_AS[mask_AS]
time_AS = time_AS[mask_AS]
mon_AS = mon_AS[mask_AS]

#---------------- Western Bay of Bengal --------------------#

ind_wBoB = (ds_WOD.lon < bounds_wBoB[1]) & (ds_WOD.lon > bounds_wBoB[0]) & (ds_WOD.lat < bounds_wBoB[3]) & (ds_WOD.lat > bounds_wBoB[2]) 

#subset gridded data
temp_wBoB = ds_WOD.temp_40_200[ind_wBoB]
doxy_wBoB = ds_WOD.doxy_40_200[ind_wBoB]
# nitrate_wBoB = ds_WOD.nitrate_40_200[ind_wBoB]
lat_wBoB = ds_WOD.lat[ind_wBoB]
lon_wBoB = ds_WOD.lon[ind_wBoB]
time_wBoB = ds_WOD.time[ind_wBoB]
mon_wBoB = time_wBoB.dt.month
    
# convert to coastal
mask_wBoB = mask_coast(np.array(lon_wBoB),np.array(lat_wBoB),np.array(ds_WOD.coastal_mask_bounds))
temp_wBoB = temp_wBoB[mask_wBoB]
doxy_wBoB = doxy_wBoB[mask_wBoB]
# nitrate_wBoB = nitrate_wBoB[mask_wBoB]
lat_wBoB = lat_wBoB[mask_wBoB]
lon_wBoB = lon_wBoB[mask_wBoB]
time_wBoB = time_wBoB[mask_wBoB]
mon_wBoB = mon_wBoB[mask_wBoB]

#---------------- Bay of Bengal --------------------#

ind_BoB = (ds_WOD.lon < bounds_BoB[1]) & (ds_WOD.lon > bounds_BoB[0]) & (ds_WOD.lat < bounds_BoB[3]) & (ds_WOD.lat > bounds_BoB[2]) 

#subset gridded data
temp_BoB = ds_WOD.temp_40_200[ind_BoB]
doxy_BoB = ds_WOD.doxy_40_200[ind_BoB]
# nitrate_BoB = ds_WOD.nitrate_40_200[ind_BoB]
lat_BoB = ds_WOD.lat[ind_BoB]
lon_BoB = ds_WOD.lon[ind_BoB]
time_BoB = ds_WOD.time[ind_BoB]
mon_BoB = time_BoB.dt.month

# convert to coastal
mask_BoB = mask_coast(np.array(lon_BoB),np.array(lat_BoB),np.array(ds_WOD.coastal_mask_bounds))
temp_BoB = temp_BoB[mask_BoB]
doxy_BoB = doxy_BoB[mask_BoB]
# nitrate_BoB = nitrate_BoB[mask_BoB]
lat_BoB = lat_BoB[mask_BoB]
lon_BoB = lon_BoB[mask_BoB]
time_BoB = time_BoB[mask_BoB]
mon_BoB = mon_BoB[mask_BoB]

# Arabian Sea

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_AS,posIODlat_AS,posIODlon_AS,posIODtime_AS,posIODmon_AS,posIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_AS,negIODlat_AS,negIODlon_AS,negIODtime_AS,negIODmon_AS,negIODseas_AS= IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_AS,neuIODlat_AS,neuIODlon_AS,neuIODtime_AS,neuIODmon_AS,neuIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,neuIODyears)



# wBoB

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_wBoB,posIODlat_wBoB,posIODlon_wBoB,posIODtime_wBoB,posIODmon_wBoB,posIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_wBoB,negIODlat_wBoB,negIODlon_wBoB,negIODtime_wBoB,negIODmon_wBoB,negIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_wBoB,neuIODlat_wBoB,neuIODlon_wBoB,neuIODtime_wBoB,neuIODmon_wBoB,neuIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)


# eBoB

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_BoB,posIODlat_BoB,posIODlon_BoB,posIODtime_BoB,posIODmon_BoB,posIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_BoB,negIODlat_BoB,negIODlon_BoB,negIODtime_BoB,negIODmon_BoB,negIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_BoB,neuIODlat_BoB,neuIODlon_BoB,neuIODtime_BoB,neuIODmon_BoB,neuIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,neuIODyears)

# %%
# Make Histograms 
binedges = np.linspace(0,250,12)
names = ['Positive IOD Years','Negative IOD Years','All Observed Years']
# title = ['Eastern Arabian Sea', 'Western Bay of Bengal','Eastern Bay of Bengal']
title = ['SEAS', 'WBoB','EBoB']
# colors = ['teal','orange','purple']
colors = ['#003466','#C47900']
letters = ['a','b','c','d','e','f']

fig = plt.figure(figsize=(10, 4), dpi=400)

params = {'legend.fontsize': 10,
         'axes.labelsize': 11,
         'axes.titlesize': 12,
         'xtick.labelsize':10,
         'ytick.labelsize':10}

pylab.rcParams.update(params)

#########################

data_AS = [posIODdata_AS,negIODdata_AS,doxy_AS]
data_wBoB = [posIODdata_wBoB,negIODdata_wBoB,doxy_wBoB]
data_BoB = [posIODdata_BoB,negIODdata_BoB,doxy_BoB]
time_data_AS = [posIODmon_AS,negIODmon_AS,mon_AS]
time_data_wBoB = [posIODmon_wBoB,negIODmon_wBoB,mon_wBoB]
time_data_BoB = [posIODmon_BoB,negIODmon_BoB,mon_BoB]

cnt = 1
for pp in range(3):

    if pp==0:
        pdata = data_AS[0]
        ndata = data_AS[1]
        alldata = data_AS[2]
        
        ptdata = time_data_AS[0]
        ntdata = time_data_AS[1]
        alltdata = time_data_AS[2]
        
    elif pp==1:
        pdata = data_wBoB[0]
        ndata = data_wBoB[1]
        alldata = data_wBoB[2]
        
        ptdata = time_data_wBoB[0]
        ntdata = time_data_wBoB[1]
        alltdata = time_data_wBoB[2]
        
    else:
        pdata = data_BoB[0]
        ndata = data_BoB[1]
        alldata = data_BoB[2]
        
        ptdata = time_data_BoB[0]
        ntdata = time_data_BoB[1]
        alltdata = time_data_BoB[2]

    # O2
    x1 = pdata[~np.isnan(pdata)]
    x2 = ndata[~np.isnan(ndata)]
    x3 = alldata[~np.isnan(alldata)]

    x1t = ptdata[~np.isnan(pdata)]
    x2t = ntdata[~np.isnan(ndata)]
    x3t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    # ks test

    pos_neg_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    pos_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    neg_all_ks_sf = stats.ks_2samp(x2_sf,x3_sf)

    pos_neg_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    pos_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    neg_all_ks_ws = stats.ks_2samp(x2_ws,x3_ws)

    # weights for relative frequency
    
    weights_sf = [np.zeros_like(x1_sf) + 1./len(x1_sf),
              np.zeros_like(x2_sf) + 1./len(x2_sf),
              np.zeros_like(x3_sf) + 1./len(x3_sf)]

    weights_ws = [np.zeros_like(x1_ws) + 1./len(x1_ws),
              np.zeros_like(x2_ws) + 1./len(x2_ws),
              np.zeros_like(x3_ws) + 1./len(x3_ws)]

    #subplot summer fall
    ax = fig.add_subplot(2,3,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')

    plt.hist(x1_sf,bins = binedges, weights=weights_sf[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_sf,bins = binedges, weights=weights_sf[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_title(title[pp])
    
    if cnt == 1:
        ax.set_ylabel('Summer/Fall \nRelative Frequency')
        
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.92, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_sf[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_sf[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_sf)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_sf)), x = 0.6,y=0.83, fontsize = 8)
    
    # subplot winter spring
    ax = fig.add_subplot(2,3,cnt + 3)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia')
    plt.hist(x1_ws,bins = binedges, weights=weights_ws[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_ws,bins = binedges, weights=weights_ws[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_xlabel('40-200dbar [$O_2$] ($\mu mol/ kg$)')
    if cnt == 1:
        ax.set_ylabel('Winter/Spring \nRelative Frequency')
        
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.92, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_ws[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_ws[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_ws)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_ws)), x = 0.6,y=0.83, fontsize = 8)
    
    cnt += 1

ax.legend(loc='lower center', bbox_to_anchor=(-.75, -.6),
          ncol=3, fancybox=True)

# %% [markdown]
# # Repeat for 50-225

# %%
#----------------- Arabian Sea ---------------------#

ind_AS = (ds_WOD.lon < bounds_AS[1]) & (ds_WOD.lon > bounds_AS[0]) & (ds_WOD.lat < bounds_AS[3]) & (ds_WOD.lat > bounds_AS[2]) 

#subset gridded data
temp_AS = ds_WOD.temp_50_225[ind_AS]
doxy_AS = ds_WOD.doxy_50_225[ind_AS]
# nitrate_AS = ds_WOD.nitrate_50_225[ind_AS]
lat_AS = ds_WOD.lat[ind_AS]
lon_AS = ds_WOD.lon[ind_AS]
time_AS = ds_WOD.time[ind_AS]
mon_AS = time_AS.dt.month
    
# convert to coastal
mask_AS = mask_coast(np.array(lon_AS),np.array(lat_AS),np.array(ds_WOD.coastal_mask_bounds))
temp_AS = temp_AS[mask_AS]
doxy_AS = doxy_AS[mask_AS]
# nitrate_AS = nitrate_AS[mask_AS]
lat_AS = lat_AS[mask_AS]
lon_AS = lon_AS[mask_AS]
time_AS = time_AS[mask_AS]
mon_AS = mon_AS[mask_AS]

#---------------- Western Bay of Bengal --------------------#

ind_wBoB = (ds_WOD.lon < bounds_wBoB[1]) & (ds_WOD.lon > bounds_wBoB[0]) & (ds_WOD.lat < bounds_wBoB[3]) & (ds_WOD.lat > bounds_wBoB[2]) 

#subset gridded data
temp_wBoB = ds_WOD.temp_50_225[ind_wBoB]
doxy_wBoB = ds_WOD.doxy_50_225[ind_wBoB]
# nitrate_wBoB = ds_WOD.nitrate_50_225[ind_wBoB]
lat_wBoB = ds_WOD.lat[ind_wBoB]
lon_wBoB = ds_WOD.lon[ind_wBoB]
time_wBoB = ds_WOD.time[ind_wBoB]
mon_wBoB = time_wBoB.dt.month
    
# convert to coastal
mask_wBoB = mask_coast(np.array(lon_wBoB),np.array(lat_wBoB),np.array(ds_WOD.coastal_mask_bounds))
temp_wBoB = temp_wBoB[mask_wBoB]
doxy_wBoB = doxy_wBoB[mask_wBoB]
# nitrate_wBoB = nitrate_wBoB[mask_wBoB]
lat_wBoB = lat_wBoB[mask_wBoB]
lon_wBoB = lon_wBoB[mask_wBoB]
time_wBoB = time_wBoB[mask_wBoB]
mon_wBoB = mon_wBoB[mask_wBoB]

#---------------- Bay of Bengal --------------------#

ind_BoB = (ds_WOD.lon < bounds_BoB[1]) & (ds_WOD.lon > bounds_BoB[0]) & (ds_WOD.lat < bounds_BoB[3]) & (ds_WOD.lat > bounds_BoB[2]) 

#subset gridded data
temp_BoB = ds_WOD.temp_50_225[ind_BoB]
doxy_BoB = ds_WOD.doxy_50_225[ind_BoB]
# nitrate_BoB = ds_WOD.nitrate_50_225[ind_BoB]
lat_BoB = ds_WOD.lat[ind_BoB]
lon_BoB = ds_WOD.lon[ind_BoB]
time_BoB = ds_WOD.time[ind_BoB]
mon_BoB = time_BoB.dt.month

# convert to coastal
mask_BoB = mask_coast(np.array(lon_BoB),np.array(lat_BoB),np.array(ds_WOD.coastal_mask_bounds))
temp_BoB = temp_BoB[mask_BoB]
doxy_BoB = doxy_BoB[mask_BoB]
# nitrate_BoB = nitrate_BoB[mask_BoB]
lat_BoB = lat_BoB[mask_BoB]
lon_BoB = lon_BoB[mask_BoB]
time_BoB = time_BoB[mask_BoB]
mon_BoB = mon_BoB[mask_BoB]

# Arabian Sea

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_AS,posIODlat_AS,posIODlon_AS,posIODtime_AS,posIODmon_AS,posIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_AS,negIODlat_AS,negIODlon_AS,negIODtime_AS,negIODmon_AS,negIODseas_AS= IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_AS,neuIODlat_AS,neuIODlon_AS,neuIODtime_AS,neuIODmon_AS,neuIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,neuIODyears)



# wBoB

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_wBoB,posIODlat_wBoB,posIODlon_wBoB,posIODtime_wBoB,posIODmon_wBoB,posIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_wBoB,negIODlat_wBoB,negIODlon_wBoB,negIODtime_wBoB,negIODmon_wBoB,negIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_wBoB,neuIODlat_wBoB,neuIODlon_wBoB,neuIODtime_wBoB,neuIODmon_wBoB,neuIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)


# eBoB

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_BoB,posIODlat_BoB,posIODlon_BoB,posIODtime_BoB,posIODmon_BoB,posIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_BoB,negIODlat_BoB,negIODlon_BoB,negIODtime_BoB,negIODmon_BoB,negIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_BoB,neuIODlat_BoB,neuIODlon_BoB,neuIODtime_BoB,neuIODmon_BoB,neuIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,neuIODyears)

# %%
# Make Histograms 
binedges = np.linspace(0,250,12)
names = ['Positive IOD Years','Negative IOD Years','All Observed Years']
# title = ['Eastern Arabian Sea', 'Western Bay of Bengal','Eastern Bay of Bengal']
title = ['SEAS', 'WBoB','EBoB']
# colors = ['teal','orange','purple']
colors = ['#003466','#C47900']
letters = ['a','b','c','d','e','f']

fig = plt.figure(figsize=(10, 4), dpi=400)

params = {'legend.fontsize': 10,
         'axes.labelsize': 11,
         'axes.titlesize': 12,
         'xtick.labelsize':10,
         'ytick.labelsize':10}

pylab.rcParams.update(params)

#########################

data_AS = [posIODdata_AS,negIODdata_AS,doxy_AS]
data_wBoB = [posIODdata_wBoB,negIODdata_wBoB,doxy_wBoB]
data_BoB = [posIODdata_BoB,negIODdata_BoB,doxy_BoB]
time_data_AS = [posIODmon_AS,negIODmon_AS,mon_AS]
time_data_wBoB = [posIODmon_wBoB,negIODmon_wBoB,mon_wBoB]
time_data_BoB = [posIODmon_BoB,negIODmon_BoB,mon_BoB]

cnt = 1
for pp in range(3):

    if pp==0:
        pdata = data_AS[0]
        ndata = data_AS[1]
        alldata = data_AS[2]
        
        ptdata = time_data_AS[0]
        ntdata = time_data_AS[1]
        alltdata = time_data_AS[2]
        
    elif pp==1:
        pdata = data_wBoB[0]
        ndata = data_wBoB[1]
        alldata = data_wBoB[2]
        
        ptdata = time_data_wBoB[0]
        ntdata = time_data_wBoB[1]
        alltdata = time_data_wBoB[2]
        
    else:
        pdata = data_BoB[0]
        ndata = data_BoB[1]
        alldata = data_BoB[2]
        
        ptdata = time_data_BoB[0]
        ntdata = time_data_BoB[1]
        alltdata = time_data_BoB[2]

    # O2
    x1 = pdata[~np.isnan(pdata)]
    x2 = ndata[~np.isnan(ndata)]
    x3 = alldata[~np.isnan(alldata)]

    x1t = ptdata[~np.isnan(pdata)]
    x2t = ntdata[~np.isnan(ndata)]
    x3t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    # ks test

    pos_neg_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    pos_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    neg_all_ks_sf = stats.ks_2samp(x2_sf,x3_sf)

    pos_neg_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    pos_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    neg_all_ks_ws = stats.ks_2samp(x2_ws,x3_ws)

    # weights for relative frequency
    
    weights_sf = [np.zeros_like(x1_sf) + 1./len(x1_sf),
              np.zeros_like(x2_sf) + 1./len(x2_sf),
              np.zeros_like(x3_sf) + 1./len(x3_sf)]

    weights_ws = [np.zeros_like(x1_ws) + 1./len(x1_ws),
              np.zeros_like(x2_ws) + 1./len(x2_ws),
              np.zeros_like(x3_ws) + 1./len(x3_ws)]

    #subplot summer fall
    ax = fig.add_subplot(2,3,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')

    plt.hist(x1_sf,bins = binedges, weights=weights_sf[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_sf,bins = binedges, weights=weights_sf[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_title(title[pp])
    
    if cnt == 1:
        ax.set_ylabel('Summer/Fall \nRelative Frequency')
        
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.90)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_sf[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_sf[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_sf)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_sf)), x = 0.6,y=0.83, fontsize = 8)
    
    # subplot winter spring
    ax = fig.add_subplot(2,3,cnt + 3)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia')
    plt.hist(x1_ws,bins = binedges, weights=weights_ws[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_ws,bins = binedges, weights=weights_ws[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_xlabel('50-225dbar [$O_2$] ($\mu mol/ kg$)')
    if cnt == 1:
        ax.set_ylabel('Winter/Spring \nRelative Frequency')
        
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.90)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_ws[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_ws[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_ws)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_ws)), x = 0.6,y=0.83, fontsize = 8)
    
    cnt += 1

ax.legend(loc='lower center', bbox_to_anchor=(-.75, -.6),
          ncol=3, fancybox=True)

# %% [markdown]
# # Redo for WOD18

# %%
# AWG
ds_WOD = xr.open_dataset('../data/wod18_processed.nc')
ds_WOD

# %%
# Arabian Sea

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_AS,posIODlat_AS,posIODlon_AS,posIODtime_AS,posIODmon_AS,posIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_AS,negIODlat_AS,negIODlon_AS,negIODtime_AS,negIODmon_AS,negIODseas_AS= IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_AS,neuIODlat_AS,neuIODlon_AS,neuIODtime_AS,neuIODmon_AS,neuIODseas_AS = IOD_year_group(doxy_AS,
                                             lat_AS,lon_AS,time_AS,
                                             IODyear_begin,IODyear_end,neuIODyears)



# nwBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_nwBoB,posIODlat_nwBoB,posIODlon_nwBoB,posIODtime_nwBoB,posIODmon_nwBoB,posIODseas_nwBoB = IOD_year_group(doxy_nwBoB,
                                             lat_nwBoB,lon_nwBoB,time_nwBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_nwBoB,negIODlat_nwBoB,negIODlon_nwBoB,negIODtime_nwBoB,negIODmon_nwBoB,negIODseas_nwBoB = IOD_year_group(doxy_nwBoB,
                                             lat_nwBoB,lon_nwBoB,time_nwBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_nwBoB,neuIODlat_nwBoB,neuIODlon_nwBoB,neuIODtime_nwBoB,neuIODmon_nwBoB,neuIODseas_nwBoB = IOD_year_group(doxy_nwBoB,
                                             lat_nwBoB,lon_nwBoB,time_nwBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)





# wBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_swBoB,posIODlat_swBoB,posIODlon_swBoB,posIODtime_swBoB,posIODmon_swBoB,posIODseas_swBoB = IOD_year_group(doxy_swBoB,
                                             lat_swBoB,lon_swBoB,time_swBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_swBoB,negIODlat_swBoB,negIODlon_swBoB,negIODtime_swBoB,negIODmon_swBoB,negIODseas_swBoB = IOD_year_group(doxy_swBoB,
                                             lat_swBoB,lon_swBoB,time_swBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_swBoB,neuIODlat_swBoB,neuIODlon_swBoB,neuIODtime_swBoB,neuIODmon_swBoB,neuIODseas_swBoB = IOD_year_group(doxy_swBoB,
                                             lat_swBoB,lon_swBoB,time_swBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)





# wBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_wBoB,posIODlat_wBoB,posIODlon_wBoB,posIODtime_wBoB,posIODmon_wBoB,posIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_wBoB,negIODlat_wBoB,negIODlon_wBoB,negIODtime_wBoB,negIODmon_wBoB,negIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_wBoB,neuIODlat_wBoB,neuIODlon_wBoB,neuIODtime_wBoB,neuIODmon_wBoB,neuIODseas_wBoB = IOD_year_group(doxy_wBoB,
                                             lat_wBoB,lon_wBoB,time_wBoB,
                                             IODyear_begin,IODyear_end,neuIODyears)




# eBoB

# 10-200

####################################
# average over the positive IOD years -------------------------------------------# 
posIODdata_BoB,posIODlat_BoB,posIODlon_BoB,posIODtime_BoB,posIODmon_BoB,posIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,posIODyears)

# average over the positive IOD years -------------------------------------------# 
negIODdata_BoB,negIODlat_BoB,negIODlon_BoB,negIODtime_BoB,negIODmon_BoB,negIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,negIODyears)



# average over the positive IOD years -------------------------------------------# 
neuIODdata_BoB,neuIODlat_BoB,neuIODlon_BoB,neuIODtime_BoB,neuIODmon_BoB,neuIODseas_BoB = IOD_year_group(doxy_BoB,
                                             lat_BoB,lon_BoB,time_BoB,
                                             IODyear_begin,IODyear_end,neuIODyears)

# %%
# Make Histograms 
binedges = np.linspace(0,250,12)
names = ['Positive IOD Years','Negative IOD Years','All Observed Years']
# title = ['Eastern Arabian Sea', 'Western Bay of Bengal','Eastern Bay of Bengal']
title = ['SEAS', 'WBoB','EBoB']
# colors = ['teal','orange','purple']
colors = ['#003466','#C47900']
letters = ['a','b','c','d','e','f']

fig = plt.figure(figsize=(10, 4), dpi=400)

params = {'legend.fontsize': 10,
         'axes.labelsize': 11,
         'axes.titlesize': 12,
         'xtick.labelsize':10,
         'ytick.labelsize':10}

pylab.rcParams.update(params)

#########################

data_AS = [posIODdata_AS,negIODdata_AS,doxy_AS]
data_wBoB = [posIODdata_wBoB,negIODdata_wBoB,doxy_wBoB]
data_BoB = [posIODdata_BoB,negIODdata_BoB,doxy_BoB]
time_data_AS = [posIODmon_AS,negIODmon_AS,mon_AS]
time_data_wBoB = [posIODmon_wBoB,negIODmon_wBoB,mon_wBoB]
time_data_BoB = [posIODmon_BoB,negIODmon_BoB,mon_BoB]

cnt = 1
for pp in range(3):

    if pp==0:
        pdata = data_AS[0]
        ndata = data_AS[1]
        alldata = data_AS[2]
        
        ptdata = time_data_AS[0]
        ntdata = time_data_AS[1]
        alltdata = time_data_AS[2]
        
    elif pp==1:
        pdata = data_wBoB[0]
        ndata = data_wBoB[1]
        alldata = data_wBoB[2]
        
        ptdata = time_data_wBoB[0]
        ntdata = time_data_wBoB[1]
        alltdata = time_data_wBoB[2]
        
    else:
        pdata = data_BoB[0]
        ndata = data_BoB[1]
        alldata = data_BoB[2]
        
        ptdata = time_data_BoB[0]
        ntdata = time_data_BoB[1]
        alltdata = time_data_BoB[2]

    # O2
    x1 = pdata[~np.isnan(pdata)]
    x2 = ndata[~np.isnan(ndata)]
    x3 = alldata[~np.isnan(alldata)]

    x1t = ptdata[~np.isnan(pdata)]
    x2t = ntdata[~np.isnan(ndata)]
    x3t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    # ks test

    pos_neg_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    pos_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    neg_all_ks_sf = stats.ks_2samp(x2_sf,x3_sf)

    pos_neg_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    pos_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    neg_all_ks_ws = stats.ks_2samp(x2_ws,x3_ws)

    # weights for relative frequency
    
    weights_sf = [np.zeros_like(x1_sf) + 1./len(x1_sf),
              np.zeros_like(x2_sf) + 1./len(x2_sf),
              np.zeros_like(x3_sf) + 1./len(x3_sf)]

    weights_ws = [np.zeros_like(x1_ws) + 1./len(x1_ws),
              np.zeros_like(x2_ws) + 1./len(x2_ws),
              np.zeros_like(x3_ws) + 1./len(x3_ws)]

    #subplot summer fall
    ax = fig.add_subplot(2,3,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')

    plt.hist(x1_sf,bins = binedges, weights=weights_sf[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_sf,bins = binedges, weights=weights_sf[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_title(title[pp])
    
    if cnt == 1:
        ax.set_ylabel('Summer/Fall \nRelative Frequency')
        
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.92, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_sf[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_sf[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_sf)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_sf)), x = 0.6,y=0.83, fontsize = 8)
    
    # subplot winter spring
    ax = fig.add_subplot(2,3,cnt + 3)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia')
    plt.hist(x1_ws,bins = binedges, weights=weights_ws[0],
                 alpha=1,color = colors[0], label=names[0])
    plt.hist(x2_ws,bins = binedges, weights=weights_ws[1],
                 alpha=0.75,color = colors[1], label=names[1])
    plt.axvline(x=hyp_thresh, color = 'silver',linestyle = '--',linewidth = 0.5)
    ax.set_ylim([0,0.45])
    ax.set_xlim([0,250])
    ax.set_xlabel('50-200dbar [$O_2$] ($\mu mol/ kg$)')
    if cnt == 1:
        ax.set_ylabel('Winter/Spring \nRelative Frequency')
        
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.92, fontsize = 8)
    add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_ws[0],4)), x = 0.6,y=0.75, fontsize = 8)
    add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_ws[1],4)), x = 0.6,y=0.67, fontsize = 8)
    add_text(ax, 'pIOD: ' + str(len(x1_ws)), x = 0.6,y=0.91, fontsize = 8)
    add_text(ax, 'nIOD: ' + str(len(x2_ws)), x = 0.6,y=0.83, fontsize = 8)
    
    cnt += 1

ax.legend(loc='lower center', bbox_to_anchor=(-.75, -.6),
          ncol=3, fancybox=True)
