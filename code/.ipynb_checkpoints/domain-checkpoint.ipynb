# %% [markdown]
# # Setup
#
# bathymetry: https://www.fatiando.org/harmonica/dev/sample_data/earth_topography.html

# %%
# add in the sla and chl observation lines 

# import your standard packages
# %run pkgs.py
# %run pars.py

# import your local functions
sys.path.insert(1, '../')
from local_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline
# Out:
# Default libraries loaded.

# %% [markdown]
# # Paths and Parameters

# %%
figpath = '../figures/'

# %% [markdown]
# # Get Data

# %%
ds_WOD = xr.open_dataset('../data/wod_coastal_processed.nc')
ds_WOD
# Out:
# <xarray.Dataset>
# Dimensions:                (time_eAS: 23602, time_eBoB: 20909, time_wAS: 24433, time_wBoB: 2926)
# Coordinates:
#   * time_wAS               (time_wAS) datetime64[ns] 1905-12-15 ... 2020-05-23
#   * time_eAS               (time_eAS) datetime64[ns] 1770-01-01 ... 2020-05-31
#   * time_wBoB              (time_wBoB) datetime64[ns] 1827-10-10 ... 2020-05-28
#   * time_eBoB              (time_eBoB) datetime64[ns] 1770-01-01 ... 2020-05-29
# Data variables:
#     lat_wAS                (time_wAS) float32 ...
#     lon_wAS                (time_wAS) float32 ...
#     mon_wAS                (time_wAS) int64 ...
#     seas_wAS               (time_wAS) int64 ...
#     lat_eAS                (time_eAS) float32 ...
#     lon_eAS                (time_eAS) float32 ...
#     mon_eAS                (time_eAS) int64 ...
#     seas_eAS               (time_eAS) int64 ...
#     lat_wBoB               (time_wBoB) float32 ...
#     lon_wBoB               (time_wBoB) float32 ...
#     mon_wBoB               (time_wBoB) int64 ...
#     seas_wBoB              (time_wBoB) int64 ...
#     lat_eBoB               (time_eBoB) float32 ...
#     lon_eBoB               (time_eBoB) float32 ...
#     mon_eBoB               (time_eBoB) int64 ...
#     seas_eBoB              (time_eBoB) int64 ...
#     temp_wAS_50_200        (time_wAS) float64 ...
#     sal_wAS_50_200         (time_wAS) float64 ...
#     doxy_wAS_50_200        (time_wAS) float64 ...
#     nitrate_wAS_50_200     (time_wAS) float64 ...
#     phosphate_wAS_50_200   (time_wAS) float64 ...
#     O2_sat_wAS_50_200      (time_wAS) float64 ...
#     temp_eAS_50_200        (time_eAS) float64 ...
#     sal_eAS_50_200         (time_eAS) float64 ...
#     doxy_eAS_50_200        (time_eAS) float64 ...
#     nitrate_eAS_50_200     (time_eAS) float64 ...
#     phosphate_eAS_50_200   (time_eAS) float64 ...
#     O2_sat_eAS_50_200      (time_eAS) float64 ...
#     temp_wBoB_50_200       (time_wBoB) float64 ...
#     tsal_wBoB_50_200       (time_wBoB) float64 ...
#     doxy_wBoB_50_200       (time_wBoB) float64 ...
#     nitrate_wBoB_50_200    (time_wBoB) float64 ...
#     phosphate_wBoB_50_200  (time_wBoB) float64 ...
#     O2_sat_wBoB_50_200     (time_wBoB) float64 ...
#     temp_eBoB_50_200       (time_eBoB) float64 ...
#     sal_eBoB_50_200        (time_eBoB) float64 ...
#     doxy_eBoB_50_200       (time_eBoB) float64 ...
#     nitrate_eBoB_50_200    (time_eBoB) float64 ...
#     phosphate_eBoB_50_200  (time_eBoB) float64 ...
#     O2_sat_eBoB_50_200     (time_eBoB) float64 ...
#     temp_wAS_40_200        (time_wAS) float64 ...
#     sal_wAS_40_200         (time_wAS) float64 ...
#     doxy_wAS_40_200        (time_wAS) float64 ...
#     nitrate_wAS_40_200     (time_wAS) float64 ...
#     phosphate_wAS_40_200   (time_wAS) float64 ...
#     O2_sat_wAS_40_200      (time_wAS) float64 ...
#     temp_eAS_40_200        (time_eAS) float64 ...
#     sal_eAS_40_200         (time_eAS) float64 ...
#     doxy_eAS_40_200        (time_eAS) float64 ...
#     nitrate_eAS_40_200     (time_eAS) float64 ...
#     phosphate_eAS_40_200   (time_eAS) float64 ...
#     O2_sat_eAS_40_200      (time_eAS) float64 ...
#     temp_wBoB_40_200       (time_wBoB) float64 ...
#     tsal_wBoB_40_200       (time_wBoB) float64 ...
#     doxy_wBoB_40_200       (time_wBoB) float64 ...
#     nitrate_wBoB_40_200    (time_wBoB) float64 ...
#     phosphate_wBoB_40_200  (time_wBoB) float64 ...
#     O2_sat_wBoB_40_200     (time_wBoB) float64 ...
#     temp_eBoB_40_200       (time_eBoB) float64 ...
#     sal_eBoB_40_200        (time_eBoB) float64 ...
#     doxy_eBoB_40_200       (time_eBoB) float64 ...
#     nitrate_eBoB_40_200    (time_eBoB) float64 ...
#     phosphate_eBoB_40_200  (time_eBoB) float64 ...
#     O2_sat_eBoB_40_200     (time_eBoB) float64 ...
#     temp_wAS_50_225        (time_wAS) float64 ...
#     sal_wAS_50_225         (time_wAS) float64 ...
#     doxy_wAS_50_225        (time_wAS) float64 ...
#     nitrate_wAS_50_225     (time_wAS) float64 ...
#     phosphate_wAS_50_225   (time_wAS) float64 ...
#     O2_sat_wAS_50_225      (time_wAS) float64 ...
#     temp_eAS_50_225        (time_eAS) float64 ...
#     sal_eAS_50_225         (time_eAS) float64 ...
#     doxy_eAS_50_225        (time_eAS) float64 ...
#     nitrate_eAS_50_225     (time_eAS) float64 ...
#     phosphate_eAS_50_225   (time_eAS) float64 ...
#     O2_sat_eAS_50_225      (time_eAS) float64 ...
#     temp_wBoB_50_225       (time_wBoB) float64 ...
#     tsal_wBoB_50_225       (time_wBoB) float64 ...
#     doxy_wBoB_50_225       (time_wBoB) float64 ...
#     nitrate_wBoB_50_225    (time_wBoB) float64 ...
#     phosphate_wBoB_50_225  (time_wBoB) float64 ...
#     O2_sat_wBoB_50_225     (time_wBoB) float64 ...
#     temp_eBoB_50_225       (time_eBoB) float64 ...
#     sal_eBoB_50_225        (time_eBoB) float64 ...
#     doxy_eBoB_50_225       (time_eBoB) float64 ...
#     nitrate_eBoB_50_225    (time_eBoB) float64 ...
#     phosphate_eBoB_50_225  (time_eBoB) float64 ...
#     O2_sat_eBoB_50_225     (time_eBoB) float64 ...

# %%
ds_WOD18 = xr.open_dataset('../data/wod18_coastal_processed.nc')
# ds_WOD18

# %%
ds_WOA = xr.open_dataset('../data/woa_coastal_processed.nc')
# ds_WOA

# %%
# load coastlines
ds_CL= xr.open_dataset('../data/sla_processed.nc')
# ds_CL

# %%
ds_HE = xr.open_dataset('../data/breitburg_processed.nc')
# ds_HE

# %% [markdown]
# # Number of Profiles per year

# %%
# # merge all data
data = np.concatenate((ds_WOD.doxy_wAS_50_200,ds_WOD.doxy_eAS_50_200,
                       ds_WOD.doxy_wBoB_50_200,ds_WOD.doxy_eBoB_50_200),0)
tdata = np.concatenate((ds_WOD.time_wAS,ds_WOD.time_eAS,
                       ds_WOD.time_wBoB,ds_WOD.time_eBoB),0)

data = xr.DataArray(data,dims = ['time'],coords =[tdata])

years = np.arange(np.min(data.time.dt.year),np.max(data.time.dt.year))
years

no_doxy = np.full((len(years)),0)
for yy,year in enumerate(years):
    ind = data.time.dt.year == year
    
    tmp_data = data[ind]
    no_doxy[yy] = len(tmp_data[~np.isnan(tmp_data)])

# %%
# np.nansum(no_temp[years <1940]),np.nansum(no_doxy[years <1940])

# %%
# spIODyears = [1961, 1972, 1994, 1997, 2006, 2019]
# for year in spIODyears:
#     print('temp ',year, ': ', no_temp[years == year],
#          'doxy ',year, ': ', no_doxy[years == year])

# %%
# # merge all data
data = np.concatenate((ds_WOD.temp_wAS_50_200,ds_WOD.temp_eAS_50_200,
                       ds_WOD.temp_wBoB_50_200,ds_WOD.temp_eBoB_50_200),0)
tdata = np.concatenate((ds_WOD.time_wAS,ds_WOD.time_eAS,
                       ds_WOD.time_wBoB,ds_WOD.time_eBoB),0)

data = xr.DataArray(data,dims = ['time'],coords =[tdata])

years = np.arange(np.min(data.time.dt.year),np.max(data.time.dt.year))
years

no_temp = np.full((len(years)),0)
for yy,year in enumerate(years):
    ind = data.time.dt.year == year
    
    tmp_data = data[ind]
    no_temp[yy] = len(tmp_data[~np.isnan(tmp_data)])

# %%
np.nansum(no_temp), np.nansum(no_doxy)
# Out:
# (60118, 3463)

# %% [markdown]
# # Domain Plot

# %%
# # Plotting Full Indian Ocean

params = {'legend.fontsize': 5.4,
         'axes.labelsize': 6,
         'axes.titlesize': 8,
         'xtick.labelsize':6,
         'ytick.labelsize':5.5}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,2.3),dpi=400)

#############################################################
#----------------- Temperature ---------------------#
#############################################################
ax = fig.add_subplot(131,projection= ccrs.PlateCarree())
plt.subplots_adjust(wspace = 0.15, bottom = 0.4)
# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = True)
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
g.xlocator = mticker.FixedLocator([54,78,102])
add_letter(ax, 'a', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# bathy contour ##############################################
add_single_bathy_cline(ax,200,linewidth = 1)
add_box(ax,[],clrs)

ax.set_title('Oxygen Profile Locations')

####### Hypoxia ##############################################
ax.scatter(ds_HE.lon,ds_HE.lat,s=45,marker = '*',c=hyp_clr,
                       edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4,linewidth=0.5)


#############################################################
#----------------- Oxygen ---------------------#
#############################################################
ax = fig.add_subplot(132,projection= ccrs.PlateCarree())
box = ax.get_position()
box.x0 = box.x0 - 0.05
box.x1 = box.x1 +0.015
ax.set_position(box)

# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
doxy = ds_WOD.doxy_wAS_50_200[ind]
lon = ds_WOD.lon_wAS[ind]
lat = ds_WOD.lat_wAS[ind]

print('Length Oxygen wAS: ', len(doxy))
print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())



# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
doxy = ds_WOD.doxy_eAS_50_200[ind]
lon = ds_WOD.lon_eAS[ind]
lat = ds_WOD.lat_eAS[ind]

print('Length Oxygen eAS: ', len(doxy))
print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
doxy = ds_WOD.doxy_wBoB_50_200[ind]
lon = ds_WOD.lon_wBoB[ind]
lat = ds_WOD.lat_wBoB[ind]

print('Length Oxygen wBoB: ', len(doxy))
print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
doxy = ds_WOD.doxy_eBoB_50_200[ind]
lon = ds_WOD.lon_eBoB[ind]
lat = ds_WOD.lat_eBoB[ind]

print('Length Oxygen eBoB: ', len(doxy))
print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())




# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = False)
g.ylabels_left = False
# g.ylabels_right = True
g.xlocator = mticker.FixedLocator([54,78,102])
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
add_letter(ax, 'b', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# bathy contour ##############################################
add_single_bathy_cline(ax,200,linewidth = 1)
add_box(ax,[],clrs)

ax.set_title('50-200 dbar Oxygen Values')

# countries
clr = 'lightgray'
add_text(ax, 'India', x = 0.45,y=0.68, fontsize = 8, color = clr)
add_text(ax, 'Bangladesh', x = 0.65,y=0.85, fontsize = 4, color = clr)
add_text(ax, 'Pakistan', x = 0.23,y=0.935, fontsize = 4, color = clr)
add_text(ax, 'Iran', x = 0.09,y=0.94, fontsize = 5, color = clr)
add_text(ax, 'Oman', x = 0.04,y=0.61, fontsize = 5, color = clr, rotation = 50)
add_text(ax, 'Burma', x = 0.8,y=0.7, fontsize = 4, color = clr, rotation = 0)
add_text(ax, 'Thailand', x = 0.88,y=0.5, fontsize = 3.5, color = clr, rotation = -45)
add_text(ax, 'Malaysia', x = 0.885,y=0.13, fontsize = 3.5, color = clr, rotation = -55)
add_text(ax, 'Sumatra', x = 0.85,y=0, fontsize = 3.5, color = clr, rotation = -50)
add_text(ax, 'Sri\nLanka', x = 0.6,y=0.16, fontsize = 4, color = 'k')


#############################################################
#----------------- Obs over time ---------------------#
#############################################################
lnclrs = ['indigo','magenta','k','limegreen']
ax = fig.add_subplot(133)
box = ax.get_position()
box.y0 = box.y0 - 0.25
ax.set_position(box)

ax.plot(years,no_doxy, color = lnclrs[0], linewidth = 1)
ax.fill_between(x = np.array(years),y1 = no_doxy, color = lnclrs[0], alpha=0.75)
ax.axvline(x=1993,color = lnclrs[1], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1993, x2 = 2020,
                  color = lnclrs[1],alpha=0.25)
ax.axvline(x=1997,color = lnclrs[2], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1997, x2 = 2020,
                  color = lnclrs[2],alpha=0.25)
ax.set_xlim([1940,2020])
ax.set_ylim([0,150])
add_letter(ax, 'c', x = 0.01,y=0.96, fontsize = lfz, color = 'k')

ax.set_title('No. of Observations/Year')

####### Legend ##############################################
add_text(ax, 'Temp.', x = 0.05,y=0.23, fontsize = lfz, color = lnclrs[0], weight = 'bold')
add_text(ax, 'Oxy.', x = 0.05,y=0.15, fontsize = lfz, color = lnclrs[1], weight = 'bold')
add_text(ax, 'SLA', x = 0.53,y=0.93, fontsize = lfz, color = lnclrs[2], weight = 'bold')
add_text(ax, 'CHL', x = 0.53,y=0.85, fontsize = lfz, color = lnclrs[3], weight = 'bold')


####### Legend ##############################################
ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Bay of Bengal')


ax.scatter(np.nan,np.nan,s=1.75,marker = '*',c='k',
                       edgecolor = 'k', label = 'Reported Cases of Hypoxia',linewidth=0.5)

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Bay of Bengal')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Hypoxic ($<61 \mu mol/kg$)')


ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Vulnerable ($<80 \mu mol/kg$)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = '$>80 \mu mol/kg$')




l = ax.legend(loc='lower center', bbox_to_anchor=(-1.275, -.05),
              markerscale = 4.5,ncol = 3, columnspacing = 0.5,
              facecolor = 'w',framealpha=1,handletextpad=0.05, 
              labelspacing = 0.75);

plt.savefig(figpath + 'domain.pdf', format='pdf', dpi = 400)
# Out:
# Length Oxygen wAS:  501
# Min Time wAS:  1960-11-04T00:00:00.000000000
# Max Time wAS:  2013-07-05T00:00:00.000000000
# Length Oxygen eAS:  1774
# Min Time eAS:  1948-03-14T00:00:00.000000000
# Max Time eAS:  2020-05-24T00:00:00.000000000
# Length Oxygen wBoB:  258
# Min Time wBoB:  1961-01-30T00:00:00.000000000
# Max Time wBoB:  2018-07-24T00:00:00.000000000
# Length Oxygen eBoB:  960
# Min Time eBoB:  1770-01-01T00:00:00.000000000
# Max Time eBoB:  2018-07-10T00:00:00.000000000

# %% [markdown]
# # WOD

# %%
# # Plotting Full Indian Ocean

params = {'legend.fontsize': 5.4,
         'axes.labelsize': 6,
         'axes.titlesize': 9,
         'xtick.labelsize':6,
         'ytick.labelsize':5.5}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,2.3),dpi=400)

#############################################################
#----------------- Temperature ---------------------#
#############################################################
ax = fig.add_subplot(131,projection= ccrs.PlateCarree())
plt.subplots_adjust(wspace = 0.15, bottom = 0.4)
# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.temp_wAS_50_200)
p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
print('Length Temperature wAS: ', len(ds_WOD.lon_wAS[ind]))
print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

# eAS
ind = ~np.isnan(ds_WOD.temp_eAS_50_200)
p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
print('Length Temperature eAS: ', len(ds_WOD.lon_eAS[ind]))
print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

# wBoB
ind = ~np.isnan(ds_WOD.temp_wBoB_50_200)
p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
print('Length Temperature wBoB: ', len(ds_WOD.lon_wBoB[ind]))
print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

# eBoB
ind = ~np.isnan(ds_WOD.temp_eBoB_50_200)
p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
print('Length Temperature eBoB: ', len(ds_WOD.lon_eBoB[ind]))
print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

# # # Hypoxic Events
# ax.scatter(ds_HE.lon,ds_HE.lat,s=8,marker = '*',c=hyp_clr,
#                        transform=ccrs.PlateCarree(), zorder = 4)

###### SLA ###################################################################

# add coastal hovemuller white squares and to legend
# p = ax.scatter(ds_CL.sta_lon,ds_CL.sta_lat,s=sz,marker = '.',c=sla_clr, 
#                edgecolors=sla_clr,transform=ccrs.PlateCarree(), label = 'Coastal SLA Stations')
# p = ax.scatter(ds_CL.sta_lon,ds_CL.sta_lat,s=7,marker = '.',c=sla_clr, 
#                edgecolor = 'none',transform=ccrs.PlateCarree(), zorder = 3)
# p = ax.scatter(ds_CL.sta_lon[ds_CL.loc_list],ds_CL.sta_lat[ds_CL.loc_list],s=25,
#                edgecolor = 'none',marker = '.',c='w', edgecolors='k',transform=ccrs.PlateCarree(), zorder = 3)

# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = True)
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
g.xlocator = mticker.FixedLocator([54,78,102])
add_letter(ax, 'a', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# bathy contour ##############################################
add_single_bathy_cline(ax,200,linewidth = 1)
add_box(ax,[],clrs)

ax.set_title('Temperature Profiles')

####### Hypoxia ##############################################
ax.scatter(ds_HE.lon,ds_HE.lat,s=45,marker = '*',c=hyp_clr,
                       edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4,linewidth=0.5)


#############################################################
#----------------- Oxygen ---------------------#
#############################################################
ax = fig.add_subplot(132,projection= ccrs.PlateCarree())
box = ax.get_position()
box.x0 = box.x0 - 0.05
box.x1 = box.x1 +0.015
ax.set_position(box)

# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
doxy = ds_WOD.doxy_wAS_50_200[ind]
lon = ds_WOD.lon_wAS[ind]
lat = ds_WOD.lat_wAS[ind]

print('Length Oxygen wAS: ', len(doxy))
print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())



# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
doxy = ds_WOD.doxy_eAS_50_200[ind]
lon = ds_WOD.lon_eAS[ind]
lat = ds_WOD.lat_eAS[ind]

print('Length Oxygen eAS: ', len(doxy))
print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
doxy = ds_WOD.doxy_wBoB_50_200[ind]
lon = ds_WOD.lon_wBoB[ind]
lat = ds_WOD.lat_wBoB[ind]

print('Length Oxygen wBoB: ', len(doxy))
print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
doxy = ds_WOD.doxy_eBoB_50_200[ind]
lon = ds_WOD.lon_eBoB[ind]
lat = ds_WOD.lat_eBoB[ind]

print('Length Oxygen eBoB: ', len(doxy))
print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())




# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = False)
g.ylabels_left = False
# g.ylabels_right = True
g.xlocator = mticker.FixedLocator([54,78,102])
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
add_letter(ax, 'b', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# bathy contour ##############################################
add_single_bathy_cline(ax,200,linewidth = 1)
add_box(ax,[],clrs)

ax.set_title('Oxygen Profiles')

# countries
clr = 'lightgray'
add_text(ax, 'India', x = 0.45,y=0.68, fontsize = 8, color = clr)
add_text(ax, 'Bangladesh', x = 0.65,y=0.85, fontsize = 4, color = clr)
add_text(ax, 'Pakistan', x = 0.23,y=0.935, fontsize = 4, color = clr)
add_text(ax, 'Iran', x = 0.09,y=0.94, fontsize = 5, color = clr)
add_text(ax, 'Oman', x = 0.04,y=0.61, fontsize = 5, color = clr, rotation = 50)
add_text(ax, 'Burma', x = 0.8,y=0.7, fontsize = 4, color = clr, rotation = 0)
add_text(ax, 'Thailand', x = 0.88,y=0.5, fontsize = 3.5, color = clr, rotation = -45)
add_text(ax, 'Malaysia', x = 0.885,y=0.13, fontsize = 3.5, color = clr, rotation = -55)
add_text(ax, 'Sumatra', x = 0.85,y=0, fontsize = 3.5, color = clr, rotation = -50)
add_text(ax, 'Sri\nLanka', x = 0.6,y=0.16, fontsize = 4, color = 'k')


#############################################################
#----------------- Obs over time ---------------------#
#############################################################
lnclrs = ['indigo','magenta','k','limegreen']
ax = fig.add_subplot(133)
box = ax.get_position()
box.y0 = box.y0 - 0.25
ax.set_position(box)

ax.plot(years,no_temp, color = lnclrs[0], linewidth = 1)
ax.fill_between(x = np.array(years),y1 = no_temp, color = lnclrs[0], alpha=0.75)
ax.plot(years,no_doxy, color = lnclrs[1], linewidth = 1)
ax.fill_between(x = np.array(years),y1 = no_doxy, color = lnclrs[1], alpha=0.75)
ax.axvline(x=1993,color = lnclrs[2], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1993, x2 = 2020,
                  color = lnclrs[2],alpha=0.25)
ax.axvline(x=1997,color = lnclrs[3], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1997, x2 = 2020,
                  color = lnclrs[3],alpha=0.25)
ax.set_xlim([1940,2020])
ax.set_ylim([0,2750])
add_letter(ax, 'c', x = 0.01,y=0.96, fontsize = lfz, color = 'k')

ax.set_title('No. of Observations/Year')

####### Legend ##############################################
add_text(ax, 'Temp.', x = 0.05,y=0.23, fontsize = lfz, color = lnclrs[0], weight = 'bold')
add_text(ax, 'Oxy.', x = 0.05,y=0.15, fontsize = lfz, color = lnclrs[1], weight = 'bold')
add_text(ax, 'SLA', x = 0.53,y=0.93, fontsize = lfz, color = lnclrs[2], weight = 'bold')
add_text(ax, 'CHL', x = 0.53,y=0.85, fontsize = lfz, color = lnclrs[3], weight = 'bold')


####### Legend ##############################################
ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Bay of Bengal')


ax.scatter(np.nan,np.nan,s=1.75,marker = '*',c='k',
                       edgecolor = 'k', label = 'Reported Cases of Hypoxia',linewidth=0.5)

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Bay of Bengal')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Hypoxic ($<61 \mu mol/kg$)')


ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Vulnerable ($<80 \mu mol/kg$)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = '$>80 \mu mol/kg$')




l = ax.legend(loc='lower center', bbox_to_anchor=(-1.275, -.05),
              markerscale = 4.5,ncol = 3, columnspacing = 0.5,
              facecolor = 'w',framealpha=1,handletextpad=0.05, 
              labelspacing = 0.75);

plt.savefig(figpath + 'domain.pdf', format='pdf', dpi = 400)
# Out:
# Length Temperature wAS:  21229
# Min Time wAS:  1924-11-06T00:00:00.000000000
# Max Time wAS:  2020-05-23T00:00:00.000000000
# Length Temperature eAS:  19606
# Min Time eAS:  1770-01-01T00:00:00.000000000
# Max Time eAS:  2020-05-31T00:00:00.000000000
# Length Temperature wBoB:  2317
# Min Time wBoB:  1893-03-13T00:00:00.000000000
# Max Time wBoB:  2020-05-28T00:00:00.000000000
# Length Temperature eBoB:  17221
# Min Time eBoB:  1770-01-01T00:00:00.000000000
# Max Time eBoB:  2020-05-29T00:00:00.000000000
# Length Oxygen wAS:  501
# Min Time wAS:  1960-11-04T00:00:00.000000000
# Max Time wAS:  2013-07-05T00:00:00.000000000
# Length Oxygen eAS:  1774
# Min Time eAS:  1948-03-14T00:00:00.000000000
# Max Time eAS:  2020-05-24T00:00:00.000000000
# Length Oxygen wBoB:  258
# Min Time wBoB:  1961-01-30T00:00:00.000000000
# Max Time wBoB:  2018-07-24T00:00:00.000000000
# Length Oxygen eBoB:  960
# Min Time eBoB:  1770-01-01T00:00:00.000000000
# Max Time eBoB:  2018-07-10T00:00:00.000000000

# %%
# # # Plotting Full Indian Ocean

# params = {'legend.fontsize': 6,
#          'axes.labelsize': 6,
#          'axes.titlesize': 9,
#          'xtick.labelsize':6,
#          'ytick.labelsize':6}

# pylab.rcParams.update(params)
# cmap = cmocean.cm.thermal_r

# # limits 
# cbounds = [49,104,-1,27]
# cmin = 20
# cmax = 160
# sz = 5
# # clrs = ['navy','limegreen','deeppink','purple']
# clrs = ['crimson','navy','purple','darkgreen']
# hyp_clr = '#FEE12B'
# sla_clr = '#FEE12B'
# lfz = 6
# fig = plt.figure(figsize=(17.8 / 2.54,2),dpi=400)

# #############################################################
# #----------------- Temperature ---------------------#
# #############################################################
# ax = fig.add_subplot(131,projection= ccrs.PlateCarree())
# plt.subplots_adjust(wspace = 0.15, bottom = 0.3)
# # add_bathy(ax,cbounds)

# # wAS
# ind = ~np.isnan(ds_WOD.temp_wAS_50_200)
# p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree(), label = 'WAS')
# print('Length Temperature wAS: ', len(ds_WOD.lon_wAS[ind]))
# print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
# print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

# # eAS
# ind = ~np.isnan(ds_WOD.temp_eAS_50_200)
# p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree(), label = 'EAS')
# print('Length Temperature eAS: ', len(ds_WOD.lon_eAS[ind]))
# print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
# print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

# # wBoB
# ind = ~np.isnan(ds_WOD.temp_wBoB_50_200)
# p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree(), label = 'WBoB')
# print('Length Temperature wBoB: ', len(ds_WOD.lon_wBoB[ind]))
# print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
# print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

# # eBoB
# ind = ~np.isnan(ds_WOD.temp_eBoB_50_200)
# p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree(), label = 'EBoB')
# print('Length Temperature eBoB: ', len(ds_WOD.lon_eBoB[ind]))
# print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
# print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

# # # # Hypoxic Events
# # ax.scatter(ds_HE.lon,ds_HE.lat,s=8,marker = '*',c=hyp_clr,
# #                        transform=ccrs.PlateCarree(), zorder = 4)

# ###### SLA ###################################################################

# # add coastal hovemuller white squares and to legend
# # p = ax.scatter(ds_CL.sta_lon,ds_CL.sta_lat,s=sz,marker = '.',c=sla_clr, 
# #                edgecolors=sla_clr,transform=ccrs.PlateCarree(), label = 'Coastal SLA Stations')
# # p = ax.scatter(ds_CL.sta_lon,ds_CL.sta_lat,s=7,marker = '.',c=sla_clr, 
# #                edgecolor = 'none',transform=ccrs.PlateCarree(), zorder = 3)
# # p = ax.scatter(ds_CL.sta_lon[ds_CL.loc_list],ds_CL.sta_lat[ds_CL.loc_list],s=25,
# #                edgecolor = 'none',marker = '.',c='w', edgecolors='k',transform=ccrs.PlateCarree(), zorder = 3)

# # land
# g = add_land(ax, bounds = cbounds,countries = True, rivers = True)
# # g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
# g.xlabel_style = {'size': 6}
# g.ylabel_style = {'size': 6}
# g.xlocator = mticker.FixedLocator([54,78,102])
# add_letter(ax, 'a', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# # bathy contour ##############################################
# add_single_bathy_cline(ax,200,linewidth = 1)
# add_box(ax,[],clrs)

# ax.set_title('Temperature Profiles')

# ####### Hypoxia ##############################################
# ax.scatter(np.nan,np.nan,s=1.75,marker = '*',c='k',
#                        edgecolor = 'k',transform=ccrs.PlateCarree(), label = 'Reported Cases',linewidth=0.5)
# ax.scatter(np.nan,np.nan,s=1.75,marker = '*',c='none',
#                        edgecolor = 'none',transform=ccrs.PlateCarree(), label = 'of Hypoxia')
# ax.scatter(ds_HE.lon,ds_HE.lat,s=45,marker = '*',c=hyp_clr,
#                        edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4,linewidth=0.5)


# ####### Legend ##############################################
# l = ax.legend(loc='lower center', bbox_to_anchor=(.475, -.5),
#               markerscale = 6,ncol = 3, columnspacing = 0.5,
#               facecolor = 'w',framealpha=1,handletextpad=0.05, labelspacing = 0.5);


# #############################################################
# #----------------- Oxygen ---------------------#
# #############################################################
# ax = fig.add_subplot(132,projection= ccrs.PlateCarree())
# box = ax.get_position()
# box.x0 = box.x0 - 0.05
# box.x1 = box.x1 +0.015
# ax.set_position(box)

# # add_bathy(ax,cbounds)

# # wAS
# ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
# doxy = ds_WOD.doxy_wAS_50_200
# p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=doxy[ind],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# print('Length Oxygen wAS: ', len(ds_WOD.lon_wAS[ind]))
# print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
# print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

# # eAS
# ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
# doxy = ds_WOD.doxy_eAS_50_200
# p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=doxy[ind],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# print('Length Oxygen eAS: ', len(ds_WOD.lon_eAS[ind]))
# print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
# print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

# # wBoB
# ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
# doxy = ds_WOD.doxy_wBoB_50_200
# p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=doxy[ind],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# print('Length Oxygen wBoB: ', len(ds_WOD.lon_wBoB[ind]))
# print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
# print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

# # eBoB
# ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
# doxy = ds_WOD.doxy_eBoB_50_200
# p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=doxy[ind],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# print('Length Oxygen eBoB: ', len(ds_WOD.lon_eBoB[ind]))
# print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
# print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))


# # land
# g = add_land(ax, bounds = cbounds,countries = True, rivers = True)
# g.ylabels_left = False
# # g.ylabels_right = True
# g.xlocator = mticker.FixedLocator([54,78,102])
# g.xlabel_style = {'size': 6}
# g.ylabel_style = {'size': 6}
# add_letter(ax, 'b', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# # bathy contour ##############################################
# add_single_bathy_cline(ax,200,linewidth = 1)
# add_box(ax,[],clrs)

# ax.set_title('Oxygen Profiles')

# cbar_ax = fig.add_axes([0.395, 0.15, 0.2, 0.025])
# cbar = fig.colorbar(p,cax=cbar_ax, pad=0.04, orientation = 'horizontal',ticks=[20,40,61,80,100,120,140,160])
# cbar.set_label('50-200 dbar [O2] ($\mu mol/kg$)')
# cbar.set_ticklabels(['20','40','hyp.','80','100','120','140','120','160'])

# #############################################################
# #----------------- Obs over time ---------------------#
# #############################################################
# ax = fig.add_subplot(133)
# ax.plot(years,no_temp, color = 'b', label = 'Temp.', linewidth = 1)
# ax.fill_between(x = np.array(years),y1 = no_temp, color = 'b', alpha=0.25)
# ax.plot(years,no_doxy, color = 'maroon', label = 'Oxy.', linewidth = 1)
# ax.fill_between(x = np.array(years),y1 = no_doxy, color = 'r', alpha=0.25)
# ax.axvline(x=1993,color = 'k', linewidth = 1)
# plt.fill_betweenx(y = np.arange(0,3100), x1 = 1993, x2 = 2020,
#                   color = 'k',alpha=0.25)
# ax.axvline(x=1997,color = 'g', linewidth = 1)
# plt.fill_betweenx(y = np.arange(0,3100), x1 = 1997, x2 = 2020,
#                   color = 'g',alpha=0.25)
# ax.set_xlim([1940,2020])
# ax.set_ylim([0,3000])
# add_letter(ax, 'c', x = 0.01,y=0.94, fontsize = lfz, color = 'k')

# ax.set_title('No. of Observations/Year')

# ####### Legend ##############################################
# add_text(ax, 'Temp.', x = 0.05,y=0.23, fontsize = lfz, color = 'b', weight = 'bold')
# add_text(ax, 'Oxy.', x = 0.05,y=0.15, fontsize = lfz, color = 'maroon', weight = 'bold')
# add_text(ax, 'SLA', x = 0.53,y=0.93, fontsize = lfz, color = 'k', weight = 'bold')
# add_text(ax, 'CHL', x = 0.53,y=0.85, fontsize = lfz, color = 'g', weight = 'bold')


# # cbar = add_bathy_cbar(fig,ax, lmax = 6000,pos = [0.685, 0.15, 0.2, 0.02])
# # cbar.set_label(label = 'm below sea level', color = 'k', fontsize = 6)
# # cbar.ax.tick_params(axis='x', colors='k',labelsize=5)

# plt.savefig(figpath + 'domain.pdf', format='pdf', dpi = 400)
