# %% [markdown]
# # Setup

# %%
# import your standard packages
# %run ../../global_tools/start.py

# import your local functions
from local_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline
# Out:
# Default libraries loaded.

# %% [markdown]
# # Paths and Parameters

# %%
# bounds_AS = [68,79,3,20]
# bounds_wBoB = [79,87,2,21]
# bounds_BoB = [87,100,0,23]

bounds_AS = [68,79,3,20]
bounds_wBoB = [79,87,2,16]
bounds_BoB = [87,100,0,16]

# %% [markdown]
# # Read Data

# %%
# SLA
ds_SLA = xr.open_dataset('../data/sla_to_awg.nc')
ds_SLA
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 146472)
# Coordinates:
#   * time       (time) datetime64[ns] 1958-06-01 1958-06-02 ... 2020-02-07
# Data variables:
#     daily_sla  (time) float64 ...
#     lon        (time) float64 ...
#     lat        (time) float64 ...

# %%
# WOA
ds_AWG = xr.open_dataset('../data/awg_processed.nc')
ds_AWG
# Out:
# <xarray.Dataset>
# Dimensions:                      (coastal_loc: 146472, coastal_pos: 44325, lonmin,lonmax,latmin,latmax: 4, pres: 201, time: 146472)
# Coordinates:
#     prof                         (time) int32 ...
#   * time                         (time) datetime64[ns] 1958-06-01 ... 2020-02-07
#   * pres                         (pres) int32 0 5 10 15 20 ... 985 990 995 1000
#   * coastal_loc                  (coastal_loc) int64 0 1 2 ... 146470 146471
#   * coastal_pos                  (coastal_pos) int64 0 1 2 ... 44322 44323 44324
#   * lonmin,lonmax,latmin,latmax  (lonmin,lonmax,latmin,latmax) int64 0 1 2 3
# Data variables:
#     temp                         (time, pres) float32 ...
#     psal                         (time, pres) float32 ...
#     doxy                         (time, pres) float32 ...
#     lat                          (time) float32 ...
#     lon                          (time) float32 ...
#     type                         (time) int32 ...
#     temp_anom                    (time, pres) float64 ...
#     doxy_anom                    (time, pres) float64 ...
#     psal_anom                    (time, pres) float64 ...
#     temp_40_200                  (time) float32 ...
#     doxy_40_200                  (time) float32 ...
#     temp_anom_40_200             (time) float64 ...
#     doxy_anom_40_200             (time) float64 ...
#     temp_50_200                  (time) float32 ...
#     doxy_50_200                  (time) float32 ...
#     temp_anom_50_200             (time) float64 ...
#     doxy_anom_50_200             (time) float64 ...
#     temp_60_200                  (time) float32 ...
#     doxy_60_200                  (time) float32 ...
#     temp_anom_60_200             (time) float64 ...
#     doxy_anom_60_200             (time) float64 ...
#     coastal_mask                 (coastal_loc) bool ...
#     coastal_mask_xx              (coastal_pos) float32 ...
#     coastal_mask_yy              (coastal_pos) float32 ...
#     coastal_mask_bounds          (lonmin,lonmax,latmin,latmax) float64 ...

# %% [markdown]
# # Whole Indian Ocean Scatterplots

# %%
sla = ds_SLA.daily_sla
temp = ds_AWG.temp_50_200
doxy = ds_AWG.doxy_50_200

plt.scatter(sla,temp)
plt.xlabel('sla')
plt.ylabel('temp')
# plt.ylim([0,150])
# Out:
# Text(0, 0.5, 'temp')

# %%
plt.scatter(sla,doxy)
plt.xlabel('sla')
plt.ylabel('doxy')
# Out:
# Text(0, 0.5, 'doxy')

# %% [markdown]
# # Subset for AS and BoB

# %%
#----------------- Arabian Sea ---------------------#

ind_AS = (ds_AWG.lon < bounds_AS[1]) & (ds_AWG.lon > bounds_AS[0]) & (ds_AWG.lat < bounds_AS[3]) & (ds_AWG.lat > bounds_AS[2]) 

#subset gridded data
temp_AS = np.array(ds_AWG.temp_50_200[ind_AS])
doxy_AS = np.array(ds_AWG.doxy_50_200[ind_AS])
# nitrate_AS = np.array(ds_AWG.nitrate_50_200[ind_AS])
sla_AS = np.array(ds_SLA.daily_sla[ind_AS])
lat_AS = np.array(ds_AWG.lat[ind_AS])
lon_AS = np.array(ds_AWG.lon[ind_AS])
    
# convert to coastal
mask_AS = mask_coast(lon_AS,lat_AS,np.array(ds_AWG.coastal_mask_bounds))
temp_AS = temp_AS[mask_AS]
doxy_AS = doxy_AS[mask_AS]
# nitrate_AS = nitrate_AS[mask_AS]
sla_AS = sla_AS[mask_AS]

sla_AS = sla_AS[~np.isnan(temp_AS)]
doxy_AS = doxy_AS[~np.isnan(temp_AS)]
# nitrate_AS = nitrate_AS[~np.isnan(temp_AS)]
temp_AS = temp_AS[~np.isnan(temp_AS)]

ind = np.isnan(sla_AS) | np.isnan(doxy_AS)
doxy_AS = doxy_AS[~ind]
temp_doxy_AS = temp_AS[~ind]
sla_doxy_AS = sla_AS[~ind]

ind = np.isnan(sla_AS) | np.isnan(temp_AS)
temp_AS = temp_AS[~ind]
sla_temp_AS = sla_AS[~ind]

#---------------- Western Bay of Bengal --------------------#

ind_wBoB = (ds_AWG.lon < bounds_wBoB[1]) & (ds_AWG.lon > bounds_wBoB[0]) & (ds_AWG.lat < bounds_wBoB[3]) & (ds_AWG.lat > bounds_wBoB[2]) 

#subset gridded data
temp_wBoB = np.array(ds_AWG.temp_50_200[ind_wBoB])
doxy_wBoB = np.array(ds_AWG.doxy_50_200[ind_wBoB])
# nitrate_wBoB = np.array(ds_AWG.nitrate_50_200[ind_wBoB])
sla_wBoB = np.array(ds_SLA.daily_sla[ind_wBoB])
lat_wBoB = np.array(ds_AWG.lat[ind_wBoB])
lon_wBoB = np.array(ds_AWG.lon[ind_wBoB])
    
# convert to coastal
mask_wBoB = mask_coast(lon_wBoB,lat_wBoB,np.array(ds_AWG.coastal_mask_bounds))
temp_wBoB = temp_wBoB[mask_wBoB]
doxy_wBoB = doxy_wBoB[mask_wBoB]
# nitrate_wBoB = nitrate_wBoB[mask_wBoB]
sla_wBoB = sla_wBoB[mask_wBoB]

sla_wBoB = sla_wBoB[~np.isnan(temp_wBoB)]
doxy_wBoB = doxy_wBoB[~np.isnan(temp_wBoB)]
# nitrate_wBoB = nitrate_wBoB[~np.isnan(temp_wBoB)]
temp_wBoB = temp_wBoB[~np.isnan(temp_wBoB)]

ind = np.isnan(sla_wBoB) | np.isnan(doxy_wBoB)
doxy_wBoB = doxy_wBoB[~ind]
temp_doxy_wBoB = temp_wBoB[~ind]
sla_doxy_wBoB = sla_wBoB[~ind]

ind = np.isnan(sla_wBoB) | np.isnan(temp_wBoB)
temp_wBoB = temp_wBoB[~ind]
sla_temp_wBoB = sla_wBoB[~ind]


#---------------- Bay of Bengal --------------------#

ind_BoB = (ds_AWG.lon < bounds_BoB[1]) & (ds_AWG.lon > bounds_BoB[0]) & (ds_AWG.lat < bounds_BoB[3]) & (ds_AWG.lat > bounds_BoB[2]) 

#subset gridded data
temp_BoB = np.array(ds_AWG.temp_50_200[ind_BoB])
doxy_BoB = np.array(ds_AWG.doxy_50_200[ind_BoB])
# nitrate_BoB = np.array(ds_AWG.nitrate_50_200[ind_BoB])
sla_BoB = np.array(ds_SLA.daily_sla[ind_BoB])
lat_BoB = np.array(ds_AWG.lat[ind_BoB])
lon_BoB = np.array(ds_AWG.lon[ind_BoB])
    
# convert to coastal
mask_BoB = mask_coast(lon_BoB,lat_BoB,np.array(ds_AWG.coastal_mask_bounds))
temp_BoB = temp_BoB[mask_BoB]
doxy_BoB = doxy_BoB[mask_BoB]
# nitrate_BoB = nitrate_BoB[mask_BoB]
sla_BoB = sla_BoB[mask_BoB]

ind = np.isnan(sla_BoB) | np.isnan(doxy_BoB)
doxy_BoB = doxy_BoB[~ind]
temp_doxy_BoB = temp_BoB[~ind]
sla_doxy_BoB = sla_BoB[~ind]

ind = np.isnan(sla_BoB) | np.isnan(temp_BoB)
temp_BoB = temp_BoB[~ind]
sla_temp_BoB = sla_BoB[~ind]

# nitrate_BoB = nitrate_BoB[~np.isnan(temp_BoB)]

# %% [markdown]
# # Find Correlations

# %%
# TCD/OCD Binned
slope_temp_sla, intercept_temp_sla, r_value_temp_sla, p_value_temp_sla, std_err_temp_sla,latbins,lonbins,temp_bncts_temp_sla,_ = interannual_space_correlate(ds_AWG.temp_50_200,
                                                                                                                               ds_SLA.daily_sla,
                                                                                                                               ds_AWG.lat,
                                                                                                                               ds_AWG.lon,
                                                                                                                               binwidth = 2)
slope_temp_doxy, intercept_temp_doxy, r_value_temp_doxy, p_value_temp_doxy, std_err_temp_doxy,_,_,_,doxy_bncts_temp_doxy  = interannual_space_correlate(ds_AWG.temp_50_200,
                                                                                                                                ds_AWG.doxy_50_200,
                                                                                                                                ds_AWG.lat,
                                                                                                                                ds_AWG.lon,
                                                                                                                               binwidth = 2)
# Out:
# /home/jennap/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /home/jennap/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:140: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /home/jennap/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /home/jennap/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /home/jennap/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:140: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /home/jennap/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %%
xx,yy = np.meshgrid(lonbins,latbins)
xx,yy = xx.flatten(),yy.flatten()

mask = mask_coast(xx,yy,np.array(ds_AWG.coastal_mask_bounds))
xx,yy = xx[mask],yy[mask]

# %% [markdown]
# # Plot

# %%
fig = plt.figure(figsize=(16,6),dpi=400)

sz = 10
sq_sz = 60
fsz = 8
alpha = 0.25

cmap = get_continuous_cmap(['#034f84','#92a8d1','#b7d7e8','#f0f0f0','#f7cac9','#f7786b','#c94c4c'])
# cmap = plt.cm.seismic

sp_clr = 'g'

params = {'legend.fontsize': 10,
         'axes.labelsize': 12,
         'axes.titlesize': 12,
         'xtick.labelsize':10,
         'ytick.labelsize':10}

pylab.rcParams.update(params)


##############################################################

ylim = [-0.4,0.6]
xlim = [14,32]

ax = fig.add_subplot(241)
p = ax.scatter(temp_AS,sla_temp_AS,c = sp_clr,s= sz,alpha = alpha)
ax.axhline(y=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ = stats.linregress(temp_AS,sla_temp_AS)
ax.plot(temp_AS, m*temp_AS + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_title('Eastern Arabian Sea')
# ax.set_xlabel('50-200dbar Temperature ($^\circ C$)')
ax.set_ylabel('Sea Level Anomaly (m)')
add_letter(ax, 'a', x = 0.01,y=0.92)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  - ' + str(np.round(np.abs(b),2)), x = 0.1,y=0.89, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.93, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.86, fontsize = fsz)

ax = fig.add_subplot(242)
p = ax.scatter(temp_wBoB,sla_temp_wBoB,c = sp_clr,s= sz,alpha = alpha)
ax.axhline(y=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(temp_wBoB,sla_temp_wBoB)
ax.plot(temp_wBoB, m*temp_wBoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_title('Western Bay of Bengal')
# ax.set_xlabel('Sea Level Anomaly (m)')
add_letter(ax, 'b', x = 0.01,y=0.92)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  - ' + str(np.round(np.abs(b),2)), x = 0.1,y=0.89, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.93, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.86, fontsize = fsz)

ax = fig.add_subplot(243)
p = ax.scatter(temp_BoB,sla_temp_BoB,c = sp_clr,s= sz,alpha = alpha)
ax.axhline(y=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(temp_BoB,sla_temp_BoB)
ax.plot(temp_BoB, m*temp_BoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_title('Eastern Bay of Bengal')
# ax.set_xlabel('Sea Level Anomaly (m)')
add_letter(ax, 'c', x = 0.01,y=0.92)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  - ' + str(np.round(np.abs(b),2)), x = 0.1,y=0.89, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.93, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.86, fontsize = fsz)

ax = fig.add_subplot(244,projection= ccrs.PlateCarree())

hatch_var = temp_bncts_temp_sla.flatten()[mask]

hatch_mask = hatch_var < 10

var = r_value_temp_sla.flatten()[mask]
ax.scatter(xx,yy,c = var,
               cmap = cmap,s = sq_sz,marker = 's',vmin = -1, vmax = 1,
               transform=ccrs.PlateCarree())
ax.scatter(xx[hatch_mask],yy[hatch_mask],c = var[hatch_mask],cmap = cmap,
           s = sq_sz,marker = 's',vmin = -1, vmax = 1,hatch = '//',
               transform=ccrs.PlateCarree())
g = add_land(ax, countries = True, rivers = True)
g.xlocator = mticker.FixedLocator([54,78,102])
g.xlabel_style = {'size': 10}
g.ylabel_style = {'size': 10}
add_letter(ax, 'd', x = 0.01,y=0.92)
ax.set_title('Northern Indian Ocean')
box_bounds = [bounds_AS,
         bounds_wBoB,
         bounds_BoB]  #lonmin,lonmax, latmin, latmax 
clrs = ['k','k','k']
add_box(ax,box_bounds,clrs)
add_text(ax, 'EAS', x = 0.46,y=0.56, fontsize = fsz, color = 'w')
add_text(ax, 'WBoB', x = 0.58,y=0.59, fontsize = fsz, color = 'w')
add_text(ax, 'EBoB', x = 0.82,y=0.65, fontsize = fsz, color = 'w')


#-------------------------------------------------------------

ylim = [-1,210]
xlim = [14,32]

ax = fig.add_subplot(245)
ax.scatter(temp_doxy_AS,doxy_AS,c = sp_clr,s= sz,alpha = alpha)
m, b, r, p_val,_ =stats.linregress(temp_doxy_AS, doxy_AS)
ax.plot(temp_doxy_AS, m*temp_doxy_AS + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_ylabel('50-200dbar [$O_2$] ($\mu mol/ kg$)')
ax.set_xlabel('50-200dbar Temp. ($^\circ$C)')
add_letter(ax, 'e', x = 0.01,y=0.92)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  - ' + str(np.round(np.abs(b),2)), x = 0.1,y=0.89, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.93, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.86, fontsize = fsz)

ax = fig.add_subplot(246)
ax.scatter(temp_doxy_wBoB,doxy_wBoB,c = sp_clr,s= sz,alpha = alpha)
m, b, r, p_val,_ =stats.linregress(temp_doxy_wBoB, doxy_wBoB)
ax.plot(temp_doxy_wBoB, m*temp_doxy_wBoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# ax.set_yticklabels([])
ax.set_xlabel('50-200dbar Temp. ($^\circ$C)')
add_letter(ax, 'f', x = 0.01,y=0.92)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  - ' + str(np.round(np.abs(b),2)), x = 0.1,y=0.89, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.93, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.86, fontsize = fsz)

ax = fig.add_subplot(247)
ax.scatter(temp_doxy_BoB,doxy_BoB,c = sp_clr,s= sz,alpha = alpha)
m, b, r, p_val,_ =stats.linregress(temp_doxy_BoB, doxy_BoB)
ax.plot(temp_doxy_BoB, m*temp_doxy_BoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# ax.set_yticklabels([])
ax.set_xlabel('50-200dbar Temp. ($^\circ$C)')
add_letter(ax, 'g', x = 0.01,y=0.92)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  - ' + str(np.round(np.abs(b),2)), x = 0.1,y=0.89, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.93, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.86, fontsize = fsz)

ax = fig.add_subplot(248,projection= ccrs.PlateCarree())
hatch_var = doxy_bncts_temp_doxy.flatten()[mask]

hatch_mask = hatch_var < 10

var = r_value_temp_doxy.flatten()[mask]
p = ax.scatter(xx,yy,c = var,
               cmap = cmap,s = sq_sz,marker = 's',vmin = -1, vmax = 1,
               transform=ccrs.PlateCarree())
ax.scatter(xx[hatch_mask],yy[hatch_mask],c = var[hatch_mask],cmap = cmap,
           s = sq_sz,marker = 's',vmin = -1, vmax = 1,hatch = '//',
               transform=ccrs.PlateCarree())
g = add_land(ax, countries = True, rivers = True)
g.xlocator = mticker.FixedLocator([54,78,102])
g.xlabel_style = {'size': 10}
g.ylabel_style = {'size': 10}
add_letter(ax, 'h', x = 0.01,y=0.92)
box_bounds = [bounds_AS,
         bounds_wBoB,
         bounds_BoB]  #lonmin,lonmax, latmin, latmax 
clrs = ['k','k','k']
add_box(ax,box_bounds,clrs)
add_text(ax, 'EAS', x = 0.46,y=0.56, fontsize = fsz, color = 'w')
add_text(ax, 'WBoB', x = 0.58,y=0.59, fontsize = fsz, color = 'w')
add_text(ax, 'EBoB', x = 0.82,y=0.65, fontsize = fsz, color = 'w')

plt.subplots_adjust(hspace = 0.25, wspace = 0.2)

add_single_vert_cbar(fig,p,'Interannual Correlation Coefficient')
# Out:
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:74: RuntimeWarning: invalid value encountered in less
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:146: RuntimeWarning: invalid value encountered in less

# %% [markdown]
# # Individual Scatter

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 3,figsize=(16,10),dpi=200)
sz = 30
fsz = 10
alpha = 0.15

cmap = get_continuous_cmap(['#034f84','#92a8d1','#b7d7e8','#f0f0f0','#f7cac9','#f7786b','#c94c4c'])


plt.rcParams.update({'font.size': 14})

##############################################################

ylim = [14,32]
xlim = [-0.45,0.45]

ax = axes[0,0]
p = ax.scatter(sla_temp_AS,temp_AS,c = 'b',edgecolors = 'b',s= sz,alpha = alpha)
ax.axvline(x=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ = stats.linregress(sla_temp_AS, temp_AS)
ax.plot(sla_AS, m*sla_AS + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_title('Eastern Arabian Sea')
ax.set_ylabel('50-200dbar Temperature ($^\circ C$)')
add_letter(ax, 'a')
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  + ' + str(np.round(b,2)), x = 0.05,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.95, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.88, fontsize = fsz)

ax = axes[0,1]
p = ax.scatter(sla_temp_wBoB,temp_wBoB,c = 'b',edgecolors = 'b',s= sz,alpha = alpha)
ax.axvline(x=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(sla_temp_wBoB, temp_wBoB)
ax.plot(sla_wBoB, m*sla_wBoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_title('Western Bay of Bengal')
add_letter(ax, 'b')
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  + ' + str(np.round(b,2)), x = 0.05,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.95, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.88, fontsize = fsz)

ax = axes[0,2]
p = ax.scatter(sla_temp_BoB,temp_BoB,c = 'b',edgecolors = 'b',s= sz,alpha = alpha)
ax.axvline(x=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(sla_temp_BoB, temp_BoB)
ax.plot(sla_BoB, m*sla_BoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_title('Eastern Bay of Bengal')
add_letter(ax, 'c')
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  + ' + str(np.round(b,2)), x = 0.05,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.95, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.88, fontsize = fsz)

#-------------------------------------------------------------
ylim = [-50,200]
xlim = [-0.45,0.45]

ax = axes[1,0]
p = ax.scatter(sla_doxy_AS,doxy_AS,c = 'b',edgecolors = 'b',s= sz,alpha = alpha)
ax.axvline(x=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(sla_doxy_AS, doxy_AS)
ax.plot(sla_AS, m*sla_AS + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_ylabel('50-200dbar [$O_2$] ($\mu mol/ kg$)')
add_letter(ax, 'd')
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  + ' + str(np.round(b,2)), x = 0.05,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.95, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.88, fontsize = fsz)
ax.set_xlabel('Sea Level Anomaly (m)')

ax = axes[1,1]
ax.scatter(sla_doxy_wBoB,doxy_wBoB,c = 'b',edgecolors = 'b',s= sz,alpha = alpha)
ax.axvline(x=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(sla_doxy_wBoB, doxy_wBoB)
ax.plot(sla_wBoB, m*sla_wBoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
add_letter(ax, 'e')
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  + ' + str(np.round(b,2)), x = 0.05,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.95, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.88, fontsize = fsz)
ax.set_xlabel('Sea Level Anomaly (m)')

ax = axes[1,2]
ax.scatter(sla_doxy_BoB,doxy_BoB,c = 'b',edgecolors = 'b',s= sz,alpha = alpha)
ax.axvline(x=0,color = 'k',linestyle = ':')
m, b, r, p_val,_ =stats.linregress(sla_doxy_BoB, doxy_BoB)
ax.plot(sla_BoB, m*sla_BoB + b, 'k', linewidth = 2)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
add_letter(ax, 'f')
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x  + ' + str(np.round(b,2)), x = 0.05,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.6,y=0.95, fontsize = fsz)
add_text(ax, 'p-value: ' + str(np.round(p_val,4)), x = 0.6,y=0.88, fontsize = fsz)
ax.set_xlabel('Sea Level Anomaly (m)')
# Out:
# Text(0.5, 0, 'Sea Level Anomaly (m)')
