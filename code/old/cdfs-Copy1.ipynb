# %% [markdown]
# # Setup

# %%
# import your standard packages
# %run pkgs.py

# import your local functions
sys.path.insert(1, '../')
from local_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline
# Out:
# Default libraries loaded.

# %% [markdown]
# # Paths and Parameters

# %%
hyp_thresh = 61

IODyear_begin = '-06-01' # month-day of IOD year
IODyear_end = '-05-31' # month-day of year AFTER IOD year

figpath = '../figures/'

# %% [markdown]
# # Get Data

# %%
ds_WOD = xr.open_dataset('../data/wod_coastal_processed.nc')
# ds_WOD

# %%
ds_WOA = xr.open_dataset('../data/woa_coastal_processed.nc')
# ds_WOA

# %%
# DMI
ds_DMI= xr.open_dataset('../data/dmi_processed.nc')
ds_DMI

posIODyears = list(np.array(ds_DMI.pos_IOD_years))
sposIODyears = list(np.array(ds_DMI.spos_IOD_years))
negIODyears = list(np.array(ds_DMI.neg_IOD_years))
neuIODyears = list(np.array(ds_DMI.neu_IOD_years))

# %% [markdown]
# # Group Into IOD Years

# %%
depth = '50_200'
Depth = '50-200'
############################################################################################################
# Western Arabian Sea
############################################################################################################
doxy = ds_WOD['doxy_wAS_' + depth]
lat = ds_WOD.lat_wAS
lon = ds_WOD.lon_wAS
t = ds_WOD.time_wAS

# positive IOD years -------------------------------------------# 
posIODdata_wAS,_,_,posIODtime_wAS,posIODmon_wAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'wAS')
# strong positive IOD years -------------------------------------------# 
sposIODdata_wAS,_,_,sposIODtime_wAS,sposIODmon_wAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'wAS')

# negative IOD years -------------------------------------------# 
negIODdata_wAS,_,_,_,negIODmon_wAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'wAS')

# neutral IOD years -------------------------------------------# 
neuIODdata_wAS,_,_,_,neuIODmonwAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'wAS')

############################################################################################################
# Eastern Arabian Sea
############################################################################################################
doxy = ds_WOD['doxy_eAS_' + depth]
lat = ds_WOD.lat_eAS
lon = ds_WOD.lon_eAS
t = ds_WOD.time_eAS

# positive IOD years -------------------------------------------# 
posIODdata_eAS,_,_,_,posIODmon_eAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'eAS')

# strong positive IOD years -------------------------------------------# 
sposIODdata_eAS,_,_,_,sposIODmon_eAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'eAS')

# negative IOD years -------------------------------------------# 
negIODdata_eAS,_,_,_,negIODmon_eAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'eAS')

# neutral IOD years -------------------------------------------# 
neuIODdata_eAS,_,_,_,neuIODmon_eAS,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'eAS')

############################################################################################################
# Western Bay of Bengal
############################################################################################################
doxy = ds_WOD['doxy_wBoB_' + depth]
lat = ds_WOD.lat_wBoB
lon = ds_WOD.lon_wBoB
t = ds_WOD.time_wBoB

# positive IOD years -------------------------------------------# 
posIODdata_wBoB,_,_,_,posIODmon_wBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'wBoB')
# strong positive IOD years -------------------------------------------# 
sposIODdata_wBoB,_,_,_,sposIODmon_wBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'wBoB')
# negative IOD years -------------------------------------------# 
negIODdata_wBoB,_,_,_,negIODmon_wBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'wBoB')

# neutral IOD years -------------------------------------------# 
neuIODdata_wBoB,_,_,_,neuIODmon_wBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'wBoB')

############################################################################################################
# Eastern Bay of Bengal
############################################################################################################
doxy = ds_WOD['doxy_eBoB_' + depth]
lat = ds_WOD.lat_eBoB
lon = ds_WOD.lon_eBoB
t = ds_WOD.time_eBoB

# positive IOD years -------------------------------------------# 
posIODdata_eBoB,_,_,_,posIODmon_eBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'eBoB')
# strong positive IOD years -------------------------------------------# 
sposIODdata_eBoB,_,_,_,sposIODmon_eBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'eBoB')
# negative IOD years -------------------------------------------# 
negIODdata_eBoB,_,_,_,negIODmon_eBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'eBoB')

# neutral IOD years -------------------------------------------# 
neuIODdata_eBoB,_,_,_,neuIODmon_eBoB,_ = IOD_year_group(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'eBoB')

# %% [markdown]
# # CDFS

# %%
# Make Histograms 
# hatch_mask = min_mean > hyp_thresh
x = [1,2,3,4]

fig = plt.figure(figsize=(8.7 / 2.54, 1.5), dpi=400)
# ax1 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax1.set_axisbelow(True) 
# ax2 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 

params = {'legend.fontsize': 3,
         'axes.labelsize': 3.5,
         'axes.titlesize': 5.5,
         'xtick.labelsize':3,
         'ytick.labelsize':3,
         'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

# mpl.rcParams['xtick.major.size'] = 20
# mpl.rcParams['xtick.major.width'] = 4
# mpl.rcParams['xtick.minor.size'] = 10
# mpl.rcParams['xtick.minor.width'] = 2

pylab.rcParams.update(params)

text_fz = 4.5
sq_sz = 20
lfz = 3.75
width = 0.2
lw = 0.75

# clrs = ['darkgreen','darkorange','navy','darkorchid', 'darkgreen']
clrs = ['darkgreen','navy','darkorange','darkorchid', 'darkgreen']
labels = ['WOA Climatology','All Years']
letters = ['a','b','c','d','e','f','g','h']


regions = ['WAS','EAS','WBoB','EBoB']

####################################################################################################
# Bar Charts
####################################################################################################
data_wAS = [ds_WOA.doxy_wAS_50_200,posIODdata_wAS,negIODdata_wAS,sposIODdata_wAS,ds_WOD.doxy_wAS_50_200]
data_eAS = [ds_WOA.doxy_eAS_50_200,posIODdata_eAS,negIODdata_eAS,sposIODdata_eAS,ds_WOD.doxy_eAS_50_200]
data_wBoB = [ds_WOA.doxy_wBoB_50_200,posIODdata_wBoB,negIODdata_wBoB,sposIODdata_wBoB,ds_WOD.doxy_wBoB_50_200]
data_eBoB = [ds_WOA.doxy_eBoB_50_200,posIODdata_eBoB,negIODdata_eBoB,sposIODdata_eBoB,ds_WOD.doxy_eBoB_50_200]

time_data_wAS = [ds_WOA.mon_wAS,posIODmon_wAS,negIODmon_wAS,sposIODmon_wAS,ds_WOD.mon_wAS]
time_data_eAS = [ds_WOA.mon_eAS,posIODmon_eAS,negIODmon_eAS,sposIODmon_eAS,ds_WOD.mon_eAS]
time_data_wBoB = [ds_WOA.mon_wBoB,posIODmon_wBoB,negIODmon_wBoB,sposIODmon_wBoB,ds_WOD.mon_wBoB]
time_data_eBoB = [ds_WOA.mon_eBoB,posIODmon_eBoB,negIODmon_eBoB,sposIODmon_eBoB,ds_WOD.mon_eBoB]

cnt = 1
for pp in range(4):

    if pp==0:
        sdata = data_wAS[0]
        pdata = data_wAS[1]
        ndata = data_wAS[2]
        spdata = data_wAS[3]
        alldata = data_wAS[4]
        
        stdata = time_data_wAS[0]
        ptdata = time_data_wAS[1]
        ntdata = time_data_wAS[2]
        sptdata = time_data_wAS[3]
        alltdata = time_data_wAS[4]

    elif pp==1:
        sdata = data_eAS[0]
        pdata = data_eAS[1]
        ndata = data_eAS[2]
        spdata = data_eAS[3]
        alldata = data_eAS[4]
        
        stdata = time_data_eAS[0]
        ptdata = time_data_eAS[1]
        ntdata = time_data_eAS[2]
        sptdata = time_data_eAS[3]
        alltdata = time_data_eAS[4]

    elif pp==2:
        sdata = data_wBoB[0]
        pdata = data_wBoB[1]
        ndata = data_wBoB[2]
        spdata = data_wBoB[3]
        alldata = data_wBoB[4]
        
        stdata = time_data_wBoB[0]
        ptdata = time_data_wBoB[1]
        ntdata = time_data_wBoB[2]
        sptdata = time_data_wBoB[3]
        alltdata = time_data_wBoB[4]

    else:
        sdata = data_eBoB[0]
        pdata = data_eBoB[1]
        ndata = data_eBoB[2]
        spdata = data_eBoB[3]
        alldata = data_eBoB[4]
        
        stdata = time_data_eBoB[0]
        ptdata = time_data_eBoB[1]
        ntdata = time_data_eBoB[2]
        sptdata = time_data_eBoB[3]
        alltdata = time_data_eBoB[4]

    # O2
    x1 = sdata[~np.isnan(sdata)]
    x2 = pdata[~np.isnan(pdata)]
    x3 = ndata[~np.isnan(ndata)]
    x4 = spdata[~np.isnan(spdata)]
    x5 = alldata[~np.isnan(alldata)]

    x1t = stdata[~np.isnan(sdata)]
    x2t = ptdata[~np.isnan(pdata)]
    x3t = ntdata[~np.isnan(ndata)]
    x4t = sptdata[~np.isnan(spdata)]
    x5t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    ind_sf = (x4t == 6) | (x4t == 7) | (x4t == 8) | (x4t == 9) | (x4t == 10) | (x4t == 11)
    ind_ws = (x4t == 12) | (x4t == 1) | (x4t == 2) | (x4t == 3) | (x4t == 4) | (x4t ==5)

    x4_sf = x4[ind_sf]
    x4_ws = x4[ind_ws]
    
    ind_sf = (x5t == 6) | (x5t == 7) | (x5t == 8) | (x5t == 9) | (x5t == 10) | (x5t == 11)
    ind_ws = (x5t == 12) | (x5t == 1) | (x5t == 2) | (x5t == 3) | (x5t == 4) | (x5t ==5)

    x5_sf = x5[ind_sf]
    x5_ws = x5[ind_ws]
    
    # sort
    x1_sf = np.sort(x1_sf)
    x2_sf = np.sort(x2_sf)
    x3_sf = np.sort(x3_sf)
    x4_sf = np.sort(x4_sf)
    x5_sf = np.sort(x5_sf)
    
    x1_ws = np.sort(x1_ws)
    x2_ws = np.sort(x2_ws)
    x3_ws = np.sort(x3_ws)
    x4_ws = np.sort(x4_ws)
    x5_ws = np.sort(x5_ws)

    # summer/fall --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    
    # seasonal 
    tmp = np.sort(x1_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[0])
    
    # all years
    tmp = np.sort(x5_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[1])

    if cnt == 1:
        ax.set_ylabel('ECDF \nSummer/Fall', fontsize = 4,labelpad = 1.5)
    else:
        ax.set_yticklabels([])
        
    ax.set_title(regions[pp], pad = 3)
    ax.set_xticklabels([])
        
    ax.set_xlim([0,200])
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.91, fontsize = lfz)


    # winter/spring --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt + 4)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)

    # seasonal 
    tmp = np.sort(x1_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[0], label = labels[0])

    # all years
    tmp = np.sort(x5_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[1], label = labels[1])

    ax.set_xlim([0,200])
    if cnt == 1:
        ax.set_ylabel('ECDF \nWinter/Spring', fontsize = 4,labelpad = 1.5)
    else:
        ax.set_yticklabels([])
    ax.set_xlabel('50-200dbar [$O_2$] ($\mu mol/ kg$)', fontsize = 3)
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.91, fontsize = lfz)

    cnt += 1

leg = ax.legend(loc='lower center', bbox_to_anchor=(-1.23, -.95),
          ncol=5, handlelength = 2.5)

for line in leg.get_lines():
    line.set_linewidth(1.0)

plt.subplots_adjust(wspace = 0.15, bottom = 0.3)

# %%
# Make Histograms 
# hatch_mask = min_mean > hyp_thresh
x = [1,2,3,4]

fig = plt.figure(figsize=(8.7 / 2.54, 1.5), dpi=400)
# ax1 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax1.set_axisbelow(True) 
# ax2 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 

params = {'legend.fontsize': 3,
         'axes.labelsize': 3.5,
         'axes.titlesize': 5.5,
         'xtick.labelsize':3,
         'ytick.labelsize':3,
         'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

# mpl.rcParams['xtick.major.size'] = 20
# mpl.rcParams['xtick.major.width'] = 4
# mpl.rcParams['xtick.minor.size'] = 10
# mpl.rcParams['xtick.minor.width'] = 2

pylab.rcParams.update(params)

text_fz = 4.5
sq_sz = 20
lfz = 3.75
width = 0.2
lw = 0.75

# clrs = ['darkgreen','darkorange','navy','darkorchid', 'darkgreen']
clrs = ['darkgreen','navy','darkorange','darkorchid', 'darkgreen']
labels = ['All Years','Positive IOD Phases','Negative IOD Phases','Strong Positive Phases']
letters = ['a','b','c','d','e','f','g','h']


regions = ['WAS','EAS','WBoB','EBoB']

####################################################################################################
# Bar Charts
####################################################################################################
data_wAS = [ds_WOA.doxy_wAS_50_200,posIODdata_wAS,negIODdata_wAS,sposIODdata_wAS,ds_WOD.doxy_wAS_50_200]
data_eAS = [ds_WOA.doxy_eAS_50_200,posIODdata_eAS,negIODdata_eAS,sposIODdata_eAS,ds_WOD.doxy_eAS_50_200]
data_wBoB = [ds_WOA.doxy_wBoB_50_200,posIODdata_wBoB,negIODdata_wBoB,sposIODdata_wBoB,ds_WOD.doxy_wBoB_50_200]
data_eBoB = [ds_WOA.doxy_eBoB_50_200,posIODdata_eBoB,negIODdata_eBoB,sposIODdata_eBoB,ds_WOD.doxy_eBoB_50_200]

time_data_wAS = [ds_WOA.mon_wAS,posIODmon_wAS,negIODmon_wAS,sposIODmon_wAS,ds_WOD.mon_wAS]
time_data_eAS = [ds_WOA.mon_eAS,posIODmon_eAS,negIODmon_eAS,sposIODmon_eAS,ds_WOD.mon_eAS]
time_data_wBoB = [ds_WOA.mon_wBoB,posIODmon_wBoB,negIODmon_wBoB,sposIODmon_wBoB,ds_WOD.mon_wBoB]
time_data_eBoB = [ds_WOA.mon_eBoB,posIODmon_eBoB,negIODmon_eBoB,sposIODmon_eBoB,ds_WOD.mon_eBoB]

cnt = 1
for pp in range(4):

    if pp==0:
        sdata = data_wAS[0]
        pdata = data_wAS[1]
        ndata = data_wAS[2]
        spdata = data_wAS[3]
        alldata = data_wAS[4]
        
        stdata = time_data_wAS[0]
        ptdata = time_data_wAS[1]
        ntdata = time_data_wAS[2]
        sptdata = time_data_wAS[3]
        alltdata = time_data_wAS[4]

    elif pp==1:
        sdata = data_eAS[0]
        pdata = data_eAS[1]
        ndata = data_eAS[2]
        spdata = data_eAS[3]
        alldata = data_eAS[4]
        
        stdata = time_data_eAS[0]
        ptdata = time_data_eAS[1]
        ntdata = time_data_eAS[2]
        sptdata = time_data_eAS[3]
        alltdata = time_data_eAS[4]

    elif pp==2:
        sdata = data_wBoB[0]
        pdata = data_wBoB[1]
        ndata = data_wBoB[2]
        spdata = data_wBoB[3]
        alldata = data_wBoB[4]
        
        stdata = time_data_wBoB[0]
        ptdata = time_data_wBoB[1]
        ntdata = time_data_wBoB[2]
        sptdata = time_data_wBoB[3]
        alltdata = time_data_wBoB[4]

    else:
        sdata = data_eBoB[0]
        pdata = data_eBoB[1]
        ndata = data_eBoB[2]
        spdata = data_eBoB[3]
        alldata = data_eBoB[4]
        
        stdata = time_data_eBoB[0]
        ptdata = time_data_eBoB[1]
        ntdata = time_data_eBoB[2]
        sptdata = time_data_eBoB[3]
        alltdata = time_data_eBoB[4]

    # O2
    x1 = sdata[~np.isnan(sdata)]
    x2 = pdata[~np.isnan(pdata)]
    x3 = ndata[~np.isnan(ndata)]
    x4 = spdata[~np.isnan(spdata)]
    x5 = alldata[~np.isnan(alldata)]

    x1t = stdata[~np.isnan(sdata)]
    x2t = ptdata[~np.isnan(pdata)]
    x3t = ntdata[~np.isnan(ndata)]
    x4t = sptdata[~np.isnan(spdata)]
    x5t = alltdata[~np.isnan(alldata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    ind_sf = (x4t == 6) | (x4t == 7) | (x4t == 8) | (x4t == 9) | (x4t == 10) | (x4t == 11)
    ind_ws = (x4t == 12) | (x4t == 1) | (x4t == 2) | (x4t == 3) | (x4t == 4) | (x4t ==5)

    x4_sf = x4[ind_sf]
    x4_ws = x4[ind_ws]
    
    ind_sf = (x5t == 6) | (x5t == 7) | (x5t == 8) | (x5t == 9) | (x5t == 10) | (x5t == 11)
    ind_ws = (x5t == 12) | (x5t == 1) | (x5t == 2) | (x5t == 3) | (x5t == 4) | (x5t ==5)

    x5_sf = x5[ind_sf]
    x5_ws = x5[ind_ws]
    
    # sort
    x1_sf = np.sort(x1_sf)
    x2_sf = np.sort(x2_sf)
    x3_sf = np.sort(x3_sf)
    x4_sf = np.sort(x4_sf)
    x5_sf = np.sort(x5_sf)
    
    x1_ws = np.sort(x1_ws)
    x2_ws = np.sort(x2_ws)
    x3_ws = np.sort(x3_ws)
    x4_ws = np.sort(x4_ws)
    x5_ws = np.sort(x5_ws)
    
    # ks test
    if (len(x1_sf)>0) & (len(x2_sf)>0):
        pos_all_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    if (len(x1_sf)>0) & (len(x3_sf)>0):    
        neg_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    if (len(x2_sf)>0) & (len(x3_sf)>0):
        pos_neg_ks_sf = stats.ks_2samp(x2_sf,x3_sf)
    if (len(x2_sf)>0) & (len(x4_sf)>0):
        pos_spos_ks_sf = stats.ks_2samp(x2_sf,x4_sf)

    if (len(x1_ws)>0) & (len(x2_ws)>0):
        pos_all_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    if (len(x1_ws)>0) & (len(x3_ws)>0):
        neg_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    if (len(x2_ws)>0) & (len(x3_ws)>0):
        pos_neg_ks_ws = stats.ks_2samp(x2_ws,x3_ws)
    if (len(x2_ws)>0) & (len(x4_ws)>0):
        pos_spos_ks_ws = stats.ks_2samp(x2_ws,x4_ws)

    # summer/fall --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    
    # seasonal 
    tmp = np.sort(x1_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[0])
    
    # positive IOD
    tmp = np.sort(x2_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[1])
    
    # negative IOD
    tmp = np.sort(x3_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[2])
    
    # strong positive IOD 
    tmp = np.sort(x4_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[1], linestyle = '--')
    
#     ax.yaxis.grid(color='gainsboro');ax.set_axisbelow(True) 
    
    if cnt == 1:
        ax.set_ylabel('ECDF \nSummer/Fall', fontsize = 4,labelpad = 1.5)
    else:
        ax.set_yticklabels([])
        
    ax.set_title(regions[pp], pad = 3)
    ax.set_xticklabels([])
        
    ax.set_xlim([0,200])
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.91, fontsize = lfz)
    if (len(x2_sf)>1) & (len(x3_sf)>1):
        add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_sf[0],4)), x = 0.53,y=0.18, fontsize = 2.25)
        add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_sf[1],4)), x = 0.53,y=0.08, fontsize = 2.25)

    

    # winter/spring --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt + 4)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)

    # seasonal 
    tmp = np.sort(x1_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[0], label = 'All Years')

    # positive IOD
    tmp = np.sort(x2_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[1], label = 'Positive IOD Phase')
    
    # negative IOD
    tmp = np.sort(x3_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[2], label = 'Negative IOD Phase')
    
    # strong positive IOD 
    tmp = np.sort(x4_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[1], linestyle = '--',label = 'Strong Positive Phase')
    
    ax.set_xlim([0,200])
    if cnt == 1:
        ax.set_ylabel('ECDF \nWinter/Spring', fontsize = 4,labelpad = 1.5)
    else:
        ax.set_yticklabels([])
    ax.set_xlabel('50-200dbar [$O_2$] ($\mu mol/ kg$)', fontsize = 3)
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.91, fontsize = lfz)
    if (len(x2_ws)>1) & (len(x3_ws)>1):
        add_text(ax, 'K-S Stat: ' + str(np.round(pos_neg_ks_ws[0],4)), x = 0.53,y=0.18, fontsize = 2.25)
        add_text(ax, 'p-value: ' + str(np.round(pos_neg_ks_ws[1],4)), x = 0.53,y=0.08, fontsize = 2.25)
    
    cnt += 1

leg = ax.legend(loc='lower center', bbox_to_anchor=(-1.23, -.95),
          ncol=5, handlelength = 2.5)

for line in leg.get_lines():
    line.set_linewidth(1.0)

plt.subplots_adjust(wspace = 0.15, bottom = 0.3)

plt.savefig(figpath + 'cdfs_' + depth + '.pdf', format='pdf', dpi = 400)

# %% [markdown]
# # Table of Stats

# %%
# Make Histograms 
# hatch_mask = min_mean > hyp_thresh
x = [1,2,3,4]

fig = plt.figure(figsize=(8.7 / 2.54, 1.5), dpi=400)
# ax1 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax1.set_axisbelow(True) 
# ax2 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 

params = {'legend.fontsize': 3,
         'axes.labelsize': 4,
         'axes.titlesize': 5.5,
         'xtick.labelsize':4,
         'ytick.labelsize':4,
         'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

# mpl.rcParams['xtick.major.size'] = 20
# mpl.rcParams['xtick.major.width'] = 4
# mpl.rcParams['xtick.minor.size'] = 10
# mpl.rcParams['xtick.minor.width'] = 2

pylab.rcParams.update(params)

text_fz = 4.5
sq_sz = 20
lfz = 3.75
width = 0.2
lw = 0.75

# clrs = ['darkgreen','darkorange','navy','darkorchid', 'darkgreen']
clrs = ['darkgreen','navy','darkorange','darkorchid', 'darkgreen']
labels = ['All Years','Positive IOD Phases','Negative IOD Phases','Strong Positive Phases']
letters = ['a','b','c','d','e','f','g','h']


regions = ['WAS','EAS','WBoB','EBoB']

####################################################################################################
# Bar Charts
####################################################################################################
data_wAS = [ds_WOA.doxy_wAS_50_200,posIODdata_wAS,negIODdata_wAS,sposIODdata_wAS]
data_eAS = [ds_WOA.doxy_eAS_50_200,posIODdata_eAS,negIODdata_eAS,sposIODdata_eAS]
data_wBoB = [ds_WOA.doxy_wBoB_50_200,posIODdata_wBoB,negIODdata_wBoB,sposIODdata_wBoB]
data_eBoB = [ds_WOA.doxy_eBoB_50_200,posIODdata_eBoB,negIODdata_eBoB,sposIODdata_eBoB]

time_data_wAS = [ds_WOA.mon_wAS,posIODmon_wAS,negIODmon_wAS,sposIODmon_wAS]
time_data_eAS = [ds_WOA.mon_eAS,posIODmon_eAS,negIODmon_eAS,sposIODmon_eAS]
time_data_wBoB = [ds_WOA.mon_wBoB,posIODmon_wBoB,negIODmon_wBoB,sposIODmon_wBoB]
time_data_eBoB = [ds_WOA.mon_eBoB,posIODmon_eBoB,negIODmon_eBoB,sposIODmon_eBoB]

cnt = 1
for pp in range(4):

    if pp==0:
        sdata = data_wAS[0]
        pdata = data_wAS[1]
        ndata = data_wAS[2]
        spdata = data_wAS[3]
        
        stdata = time_data_wAS[0]
        ptdata = time_data_wAS[1]
        ntdata = time_data_wAS[2]
        sptdata = time_data_wAS[3]

    elif pp==1:
        sdata = data_eAS[0]
        pdata = data_eAS[1]
        ndata = data_eAS[2]
        spdata = data_eAS[3]
        
        stdata = time_data_eAS[0]
        ptdata = time_data_eAS[1]
        ntdata = time_data_eAS[2]
        sptdata = time_data_eAS[3]

    elif pp==2:
        sdata = data_wBoB[0]
        pdata = data_wBoB[1]
        ndata = data_wBoB[2]
        spdata = data_wBoB[3]
        
        stdata = time_data_wBoB[0]
        ptdata = time_data_wBoB[1]
        ntdata = time_data_wBoB[2]
        sptdata = time_data_wBoB[3]

    else:
        sdata = data_eBoB[0]
        pdata = data_eBoB[1]
        ndata = data_eBoB[2]
        spdata = data_eBoB[3]
        
        stdata = time_data_eBoB[0]
        ptdata = time_data_eBoB[1]
        ntdata = time_data_eBoB[2]
        sptdata = time_data_eBoB[3]

    # O2
    x1 = sdata[~np.isnan(sdata)]
    x2 = pdata[~np.isnan(pdata)]
    x3 = ndata[~np.isnan(ndata)]
    x4 = spdata[~np.isnan(spdata)]

    x1t = stdata[~np.isnan(sdata)]
    x2t = ptdata[~np.isnan(pdata)]
    x3t = ntdata[~np.isnan(ndata)]
    x4t = sptdata[~np.isnan(spdata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    ind_sf = (x4t == 6) | (x4t == 7) | (x4t == 8) | (x4t == 9) | (x4t == 10) | (x4t == 11)
    ind_ws = (x4t == 12) | (x4t == 1) | (x4t == 2) | (x4t == 3) | (x4t == 4) | (x4t ==5)

    x4_sf = x4[ind_sf]
    x4_ws = x4[ind_ws]
    
    
    # sort
    x1_sf = np.sort(x1_sf)
    x2_sf = np.sort(x2_sf)
    x3_sf = np.sort(x3_sf)
    x4_sf = np.sort(x4_sf)
    
    x1_ws = np.sort(x1_ws)
    x2_ws = np.sort(x2_ws)
    x3_ws = np.sort(x3_ws)
    x4_ws = np.sort(x4_ws)
    
    # ks test
    if (len(x1_sf)>0) & (len(x2_sf)>0):
        pos_all_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
        print(regions[pp],'s/f pos-all k-stat: ',pos_all_ks_sf[0], 'pos-all p-val: ',pos_all_ks_sf[1])
    if (len(x1_sf)>0) & (len(x3_sf)>0):    
        neg_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
        print('     s/f neg-all k-stat: ',neg_all_ks_sf[0], 'neg-all p-val: ',neg_all_ks_sf[1])
    if (len(x2_sf)>0) & (len(x3_sf)>0):
        pos_neg_ks_sf = stats.ks_2samp(x2_sf,x3_sf)
        print('     s/f pos-neg k-stat: ',pos_neg_ks_sf[0], 'pos-neg p-val: ',pos_neg_ks_sf[1])
    if (len(x2_sf)>0) & (len(x4_sf)>0):
        pos_spos_ks_sf = stats.ks_2samp(x2_sf,x4_sf)
        print('     s/f pos-spos k-stat: ',pos_spos_ks_sf[0], 'pos-spos p-val: ',pos_spos_ks_sf[1])

    if (len(x1_ws)>0) & (len(x2_ws)>0):
        pos_all_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
        print('     w/s pos-all k-stat: ',pos_all_ks_ws[0], 'pos-all p-val: ',pos_all_ks_ws[1])
    if (len(x1_ws)>0) & (len(x3_ws)>0):    
        neg_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
        print('     w/s neg-all k-stat: ',neg_all_ks_ws[0], 'neg-all p-val: ',neg_all_ks_ws[1])
    if (len(x2_ws)>0) & (len(x3_ws)>0):
        pos_neg_ks_ws = stats.ks_2samp(x2_ws,x3_ws)
        print('     w/s pos-neg k-stat: ',pos_neg_ks_ws[0], 'pos-neg p-val: ',pos_neg_ks_ws[1])
    if (len(x2_ws)>0) & (len(x4_ws)>0):
        pos_spos_ks_ws = stats.ks_2samp(x2_ws,x4_ws)
        print('     w/s pos-spos k-stat: ',pos_spos_ks_ws[0], 'pos-spos p-val: ',pos_spos_ks_ws[1])
# Out:
# WAS s/f pos-all k-stat:  0.2128879892037787 pos-all p-val:  0.011756702188728374
#      s/f neg-all k-stat:  0.34210526315789475 neg-all p-val:  0.004070561660079686
#      s/f pos-neg k-stat:  0.19951923076923078 pos-neg p-val:  0.24902881909892272
#      s/f pos-spos k-stat:  0.12479541734860884 pos-spos p-val:  0.6368511435933637
#      w/s pos-all k-stat:  0.19803746654772525 pos-all p-val:  0.07964030681693346
#      w/s neg-all k-stat:  0.16666666666666666 neg-all p-val:  0.24044505206363576
#      w/s pos-neg k-stat:  0.17796610169491525 pos-neg p-val:  0.29860857602406043
#      w/s pos-spos k-stat:  0.18141870684243566 pos-spos p-val:  0.5038942793445779
# EAS s/f pos-all k-stat:  0.08391343150379295 pos-all p-val:  0.16914377192164687
#      s/f neg-all k-stat:  0.17061912658927583 neg-all p-val:  0.003299294979632883
#      s/f pos-neg k-stat:  0.17113229035545166 pos-neg p-val:  0.010446524601344986
#      s/f pos-spos k-stat:  0.047996865510823786 pos-spos p-val:  0.9845591674313935
#      w/s pos-all k-stat:  0.37921390778533637 pos-all p-val:  2.1828504400901535e-18
#      w/s neg-all k-stat:  0.15999301187980433 neg-all p-val:  0.00018928826199837712
#      w/s pos-neg k-stat:  0.411282248748556 pos-neg p-val:  5.5888600122953e-17
#      w/s pos-spos k-stat:  0.14965986394557823 pos-spos p-val:  0.13060183918006452
# WBoB s/f pos-all k-stat:  0.25396825396825395 pos-all p-val:  0.2508418743925278
#      s/f neg-all k-stat:  0.20634920634920634 neg-all p-val:  0.4918175411061446
#      s/f pos-neg k-stat:  0.16666666666666666 pos-neg p-val:  0.9715397823325015
#      w/s pos-all k-stat:  0.6190476190476191 pos-all p-val:  0.7764705882352941
#      w/s neg-all k-stat:  0.26515151515151514 neg-all p-val:  0.008698692103010552
#      w/s pos-neg k-stat:  0.6818181818181818 pos-neg p-val:  0.6567164179104479
# EBoB s/f pos-all k-stat:  0.6333333333333333 pos-all p-val:  2.4424906541753444e-15
#      s/f neg-all k-stat:  0.19610136452241717 neg-all p-val:  0.0011932735341643186
#      s/f pos-neg k-stat:  0.6293859649122807 pos-neg p-val:  1.4432899320127035e-15
#      s/f pos-spos k-stat:  0.21354166666666666 pos-spos p-val:  0.6734198601331229
#      w/s pos-all k-stat:  0.26897670866743034 pos-all p-val:  9.653029237832733e-06
#      w/s neg-all k-stat:  0.22248677248677248 neg-all p-val:  1.7215546876947485e-08
#      w/s pos-neg k-stat:  0.37820324005891015 pos-neg p-val:  9.957449309538902e-10
#      w/s pos-spos k-stat:  0.28332106038291605 pos-spos p-val:  0.005086411472897789

# %%
# Make Histograms 
# hatch_mask = min_mean > hyp_thresh
x = [1,2,3,4]

fig = plt.figure(figsize=(8.7 / 2.54, 1.25), dpi=400)

params = {'legend.fontsize': 4,
         'axes.labelsize': 4,
         'axes.titlesize': 6,
         'xtick.labelsize':4,
         'ytick.labelsize':4}

pylab.rcParams.update(params)

text_fz = 4.5
sq_sz = 20
lfz = 4
width = 0.2
lw = 2

clrs = ['olivedrab','royalblue','darkorchid', 'darkgreen']
labels = ['WOA Climatology','Positive IOD Phase','Negative IOD Phase','Strong Positive Phase']

####################################################################################################
####################################################################################################

data_eBoB = [ds_WOA.doxy_eBoB_50_200,posIODdata_eBoB,negIODdata_eBoB,sposIODdata_eBoB]
time_data_eBoB = [ds_WOA.mon_eBoB,posIODmon_eBoB,negIODmon_eBoB,sposIODmon_eBoB]

sdata = data_eBoB[0]
pdata = data_eBoB[1]
ndata = data_eBoB[2]
spdata = data_eBoB[3]

stdata = time_data_eBoB[0]
ptdata = time_data_eBoB[1]
ntdata = time_data_eBoB[2]
sptdata = time_data_eBoB[3]

# O2
x1 = sdata[~np.isnan(sdata)]
x2 = pdata[~np.isnan(pdata)]
x3 = ndata[~np.isnan(ndata)]
x4 = spdata[~np.isnan(spdata)]

x1t = stdata[~np.isnan(sdata)]
x2t = ptdata[~np.isnan(pdata)]
x3t = ntdata[~np.isnan(ndata)]
x4t = sptdata[~np.isnan(spdata)]

# get seasonal indicies
ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

x1_sf = x1[ind_sf]
x1_ws = x1[ind_ws]

ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

x2_sf = x2[ind_sf]
x2_ws = x2[ind_ws]

x1_sf = np.sort(x1_sf)
x2_sf = np.sort(x2_sf)
x1_ws = np.sort(x1_ws)
x2_ws = np.sort(x2_ws)


# summer/fall --------------------------------------------------------------- #
ax = fig.add_subplot(1,2,1)
ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')
ax.axvline(x = hyp_thresh,color = 'gray',linestyle = '--', linewidth = 1)

data_all = np.concatenate([x1_sf, x2_sf])
data_all = np.sort(data_all)
n1 = len(x1_sf)
n2 = len(x2_sf)
cdf1 = np.searchsorted(x1_sf, data_all, side='right') / n1*100
cdf2 = np.searchsorted(x2_sf, data_all, side='right') / n2*100
    
ax.axhline(y = 1, color = clrs[0],linestyle = '--', linewidth = 1)
ax.axhline(y = 45,color = clrs[1],linestyle = '--', linewidth = 1)



# seasonal 
plt.plot(data_all,cdf1, linewidth = lw, color = clrs[0])

# positive IOD
plt.plot(data_all,cdf2, linewidth = lw, color = clrs[1])

ax.set_title('Summer/Fall', color = 'w')
ax.set_ylabel('Emperical Cumulative \nDistribution Function (%)', fontsize = 5)
# ax.set_xlabel('50-200dbar [O2] ($\mu mol/ kg$)')
ax.set_xlabel('Oxygen ($\mu mol/ kg$)', fontsize = 6, fontweight = 'bold')
ax.set_xlim([0,200])

[ax.spines[x].set_color('w') for x in ["bottom","top","left","right"]]
ax.xaxis.label.set_color('w')
ax.tick_params(axis='x', colors='w')
ax.yaxis.label.set_color('w')
ax.tick_params(axis='y', colors='w')
# winter/spring --------------------------------------------------------------- #
ax = fig.add_subplot(1,2,2)
ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')
ax.axvline(x = hyp_thresh,color = 'gray',linestyle = '--', linewidth = 1)

data_all = np.concatenate([x1_ws, x2_ws])
data_all = np.sort(data_all)
n1 = len(x1_ws)
n2 = len(x2_ws)
cdf1 = np.searchsorted(x1_ws, data_all, side='right') / n1*100
cdf2 = np.searchsorted(x2_ws, data_all, side='right') / n2*100
    
# seasonal 
plt.plot(data_all,cdf1, linewidth = lw, color = clrs[0], label = labels[0])

# positive IOD
plt.plot(data_all,cdf2, linewidth = lw, color = clrs[1], label = labels[1])

ax.axhline(y = 18, color = clrs[0],linestyle = '--', linewidth = 1)
ax.axhline(y = 40,color = clrs[1],linestyle = '--', linewidth = 1)


ax.set_title('Winter/Spring', color = 'w')
ax.set_xlim([0,200])
# ax.set_xlabel('50-200dbar [O2] ($\mu mol/ kg$)')
ax.set_xlabel('Oxygen ($\mu mol/ kg$)', fontsize = 6, fontweight = 'bold')

# plt.suptitle('Eastern Bay of Bengal (EBoB)', y = 1.2, fontsize = 6, color = 'w')

[ax.spines[x].set_color('w') for x in ["bottom","top","left","right"]]
ax.xaxis.label.set_color('w')
ax.tick_params(axis='x', colors='w')
ax.yaxis.label.set_color('w')
ax.tick_params(axis='y', colors='w')

ax.legend()

# %% [markdown]
# # PDFs

# %%
# Make Histograms 
# hatch_mask = min_mean > hyp_thresh
x = [1,2,3,4]

fig = plt.figure(figsize=(8.7 / 2.54, 2), dpi=400)
# ax1 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax1.set_axisbelow(True) 
# ax2 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 

params = {'legend.fontsize': 3,
         'axes.labelsize': 4,
         'axes.titlesize': 6,
         'xtick.labelsize':4,
         'ytick.labelsize':4}

pylab.rcParams.update(params)

text_fz = 4.5
sq_sz = 20
lfz = 4
width = 0.2
lw = 0.5

clrs = ['darkgreen','navy','darkorange','navy', 'darkgreen']
labels = ['All Years','Positive IOD Phase','Negative IOD Phase','Strong Positive Phase']
letters = ['a','b','c','d','e','f','g','h']


regions = ['WAS','EAS','WBoB','EBoB']

####################################################################################################
# Bar Charts
####################################################################################################
data_wAS = [ds_WOA.doxy_wAS_50_200,posIODdata_wAS,negIODdata_wAS,sposIODdata_wAS]
data_eAS = [ds_WOA.doxy_eAS_50_200,posIODdata_eAS,negIODdata_eAS,sposIODdata_eAS]
data_wBoB = [ds_WOA.doxy_wBoB_50_200,posIODdata_wBoB,negIODdata_wBoB,sposIODdata_wBoB]
data_eBoB = [ds_WOA.doxy_eBoB_50_200,posIODdata_eBoB,negIODdata_eBoB,sposIODdata_eBoB]

time_data_wAS = [ds_WOA.mon_wAS,posIODmon_wAS,negIODmon_wAS,sposIODmon_wAS]
time_data_eAS = [ds_WOA.mon_eAS,posIODmon_eAS,negIODmon_eAS,sposIODmon_eAS]
time_data_wBoB = [ds_WOA.mon_wBoB,posIODmon_wBoB,negIODmon_wBoB,sposIODmon_wBoB]
time_data_eBoB = [ds_WOA.mon_eBoB,posIODmon_eBoB,negIODmon_eBoB,sposIODmon_eBoB]

cnt = 1
for pp in range(4):

    if pp==0:
        sdata = data_wAS[0]
        pdata = data_wAS[1]
        ndata = data_wAS[2]
        spdata = data_wAS[3]
        
        stdata = time_data_wAS[0]
        ptdata = time_data_wAS[1]
        ntdata = time_data_wAS[2]
        sptdata = time_data_wAS[3]

    elif pp==1:
        sdata = data_eAS[0]
        pdata = data_eAS[1]
        ndata = data_eAS[2]
        spdata = data_eAS[3]
        
        stdata = time_data_eAS[0]
        ptdata = time_data_eAS[1]
        ntdata = time_data_eAS[2]
        sptdata = time_data_eAS[3]

    elif pp==2:
        sdata = data_wBoB[0]
        pdata = data_wBoB[1]
        ndata = data_wBoB[2]
        spdata = data_wBoB[3]
        
        stdata = time_data_wBoB[0]
        ptdata = time_data_wBoB[1]
        ntdata = time_data_wBoB[2]
        sptdata = time_data_wBoB[3]

    else:
        sdata = data_eBoB[0]
        pdata = data_eBoB[1]
        ndata = data_eBoB[2]
        spdata = data_eBoB[3]
        
        stdata = time_data_eBoB[0]
        ptdata = time_data_eBoB[1]
        ntdata = time_data_eBoB[2]
        sptdata = time_data_eBoB[3]

    # O2
    x1 = sdata[~np.isnan(sdata)]
    x2 = pdata[~np.isnan(pdata)]
    x3 = ndata[~np.isnan(ndata)]
    x4 = spdata[~np.isnan(spdata)]

    x1t = stdata[~np.isnan(sdata)]
    x2t = ptdata[~np.isnan(pdata)]
    x3t = ntdata[~np.isnan(ndata)]
    x4t = sptdata[~np.isnan(spdata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    ind_sf = (x4t == 6) | (x4t == 7) | (x4t == 8) | (x4t == 9) | (x4t == 10) | (x4t == 11)
    ind_ws = (x4t == 12) | (x4t == 1) | (x4t == 2) | (x4t == 3) | (x4t == 4) | (x4t ==5)

    x4_sf = x4[ind_sf]
    x4_ws = x4[ind_ws]

    # summer/fall --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')
    
    # seasonal 
    tmp = np.sort(x1_sf)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[0])
    
    # positive IOD
    tmp = np.sort(x2_sf)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[1])
    
    # negative IOD
    tmp = np.sort(x3_sf)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[2])
    
    # strong positive IOD 
    tmp = np.sort(x4_sf)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[1], linestyle = '--')

    
    if cnt == 1:
        ax.set_ylabel('Summer/Fall')
    else:
        ax.set_yticklabels([])
        
    ax.set_title(regions[pp])
    ax.set_xticklabels([])
        
    ax.set_xlim([0,200])
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.94, fontsize = lfz)

    # winter/spring --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt + 4)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver')

        # seasonal 
    tmp = np.sort(x1_ws)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[0], label = labels[0])
    
    # positive IOD
    tmp = np.sort(x2_ws)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[1], label = labels[1])
    
    # negative IOD
    tmp = np.sort(x3_ws)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[2], label = labels[2])
    
    # strong positive IOD 
    tmp = np.sort(x4_ws)
    if len(tmp)>1:
        kernel = stats.gaussian_kde(tmp)
        plt.plot(tmp,kernel(tmp), linewidth = lw, color = clrs[1], label = labels[3], linestyle = '--')
        
    ax.set_xlim([0,200])
    if cnt == 1:
        ax.set_ylabel('Winter/Spring')
    else:
        ax.set_yticklabels([])
    ax.set_xlabel('[O2]')
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.92, fontsize = lfz)
    
    cnt += 1

ax.legend(loc='lower center', bbox_to_anchor=(-1.2, -.65),
          ncol=4, fancybox=True)


# plt.savefig(figpath + 'hypoxia_' + depth + '.pdf', format='pdf', dpi = 400)
