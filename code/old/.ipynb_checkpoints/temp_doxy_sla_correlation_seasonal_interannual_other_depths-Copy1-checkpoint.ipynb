# %% [markdown]
# # Setup

# %%
# import your standard packages
# %run pkgs.py

# import your local functions
sys.path.insert(1, '../')
from local_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline
# Out:
# Default libraries loaded.

# %% [markdown]
# # Paths and Parameters

# %%
figpath = '../figures/'

# %% [markdown]
# ## Read Data

# %%
# SLA
ds_SLA = xr.open_dataset('../data/sla_to_woa.nc')
# ds_SLA

# %%
# SLA
ds_SLA_ia = xr.open_dataset('../data/sla_to_wod.nc')
# ds_SLA_ia

# %%
# WOD
ds_WOD = xr.open_dataset('../data/wod_coastal_processed.nc')
# ds_WOD

# %%
# WOA
ds_WOA = xr.open_dataset('../data/woa_coastal_processed.nc')
ds_WOA
# Out:
# <xarray.Dataset>
# Dimensions:                (month_eAS: 1200, month_eBoB: 1632, month_wAS: 672, month_wBoB: 288)
# Coordinates:
#   * month_wAS              (month_wAS) float64 1.0 1.0 1.0 ... 12.0 12.0 12.0
#   * month_eAS              (month_eAS) float64 1.0 1.0 1.0 ... 12.0 12.0 12.0
#   * month_wBoB             (month_wBoB) float64 1.0 1.0 1.0 ... 12.0 12.0 12.0
#   * month_eBoB             (month_eBoB) float64 1.0 1.0 1.0 ... 12.0 12.0 12.0
# Data variables:
#     lat_wAS                (month_wAS) float64 ...
#     lon_wAS                (month_wAS) float64 ...
#     mon_wAS                (month_wAS) float64 ...
#     lat_eAS                (month_eAS) float64 ...
#     lon_eAS                (month_eAS) float64 ...
#     mon_eAS                (month_eAS) float64 ...
#     lat_wBoB               (month_wBoB) float64 ...
#     lon_wBoB               (month_wBoB) float64 ...
#     mon_wBoB               (month_wBoB) float64 ...
#     lat_eBoB               (month_eBoB) float64 ...
#     lon_eBoB               (month_eBoB) float64 ...
#     mon_eBoB               (month_eBoB) float64 ...
#     temp_wAS_50_200        (month_wAS) float64 ...
#     sal_wAS_50_200         (month_wAS) float64 ...
#     doxy_wAS_50_200        (month_wAS) float64 ...
#     nitrate_wAS_50_200     (month_wAS) float64 ...
#     phosphate_wAS_50_200   (month_wAS) float64 ...
#     O2_sat_wAS_50_200      (month_wAS) float64 ...
#     temp_eAS_50_200        (month_eAS) float64 ...
#     sal_eAS_50_200         (month_eAS) float64 ...
#     doxy_eAS_50_200        (month_eAS) float64 ...
#     nitrate_eAS_50_200     (month_eAS) float64 ...
#     phosphate_eAS_50_200   (month_eAS) float64 ...
#     O2_sat_eAS_50_200      (month_eAS) float64 ...
#     temp_wBoB_50_200       (month_wBoB) float64 ...
#     sal_wBoB_50_200        (month_wBoB) float64 ...
#     doxy_wBoB_50_200       (month_wBoB) float64 ...
#     nitrate_wBoB_50_200    (month_wBoB) float64 ...
#     phosphate_wBoB_50_200  (month_wBoB) float64 ...
#     O2_sat_wBoB_50_200     (month_wBoB) float64 ...
#     temp_eBoB_50_200       (month_eBoB) float64 ...
#     sal_eBoB_50_200        (month_eBoB) float64 ...
#     doxy_eBoB_50_200       (month_eBoB) float64 ...
#     nitrate_eBoB_50_200    (month_eBoB) float64 ...
#     phosphate_eBoB_50_200  (month_eBoB) float64 ...
#     O2_sat_eBoB_50_200     (month_eBoB) float64 ...
#     temp_wAS_40_200        (month_wAS) float64 ...
#     sal_wAS_40_200         (month_wAS) float64 ...
#     doxy_wAS_40_200        (month_wAS) float64 ...
#     nitrate_wAS_40_200     (month_wAS) float64 ...
#     phosphate_wAS_40_200   (month_wAS) float64 ...
#     O2_sat_wAS_40_200      (month_wAS) float64 ...
#     temp_eAS_40_200        (month_eAS) float64 ...
#     sal_eAS_40_200         (month_eAS) float64 ...
#     doxy_eAS_40_200        (month_eAS) float64 ...
#     nitrate_eAS_40_200     (month_eAS) float64 ...
#     phosphate_eAS_40_200   (month_eAS) float64 ...
#     O2_sat_eAS_40_200      (month_eAS) float64 ...
#     temp_wBoB_40_200       (month_wBoB) float64 ...
#     sal_wBoB_40_200        (month_wBoB) float64 ...
#     doxy_wBoB_40_200       (month_wBoB) float64 ...
#     nitrate_wBoB_40_200    (month_wBoB) float64 ...
#     phosphate_wBoB_40_200  (month_wBoB) float64 ...
#     O2_sat_wBoB_40_200     (month_wBoB) float64 ...
#     temp_eBoB_40_200       (month_eBoB) float64 ...
#     sal_eBoB_40_200        (month_eBoB) float64 ...
#     doxy_eBoB_40_200       (month_eBoB) float64 ...
#     nitrate_eBoB_40_200    (month_eBoB) float64 ...
#     phosphate_eBoB_40_200  (month_eBoB) float64 ...
#     O2_sat_eBoB_40_200     (month_eBoB) float64 ...
#     temp_wAS_50_225        (month_wAS) float64 ...
#     sal_wAS_50_225         (month_wAS) float64 ...
#     doxy_wAS_50_225        (month_wAS) float64 ...
#     nitrate_wAS_50_225     (month_wAS) float64 ...
#     phosphate_wAS_50_225   (month_wAS) float64 ...
#     O2_sat_wAS_50_225      (month_wAS) float64 ...
#     temp_eAS_50_225        (month_eAS) float64 ...
#     sal_eAS_50_225         (month_eAS) float64 ...
#     doxy_eAS_50_225        (month_eAS) float64 ...
#     nitrate_eAS_50_225     (month_eAS) float64 ...
#     phosphate_eAS_50_225   (month_eAS) float64 ...
#     O2_sat_eAS_50_225      (month_eAS) float64 ...
#     temp_wBoB_50_225       (month_wBoB) float64 ...
#     sal_wBoB_50_225        (month_wBoB) float64 ...
#     doxy_wBoB_50_225       (month_wBoB) float64 ...
#     nitrate_wBoB_50_225    (month_wBoB) float64 ...
#     phosphate_wBoB_50_225  (month_wBoB) float64 ...
#     O2_sat_wBoB_50_225     (month_wBoB) float64 ...
#     temp_eBoB_50_225       (month_eBoB) float64 ...
#     sal_eBoB_50_225        (month_eBoB) float64 ...
#     doxy_eBoB_50_225       (month_eBoB) float64 ...
#     nitrate_eBoB_50_225    (month_eBoB) float64 ...
#     phosphate_eBoB_50_225  (month_eBoB) float64 ...
#     O2_sat_eBoB_50_225     (month_eBoB) float64 ...

# %% [markdown]
# # Oxygen vs SLA

# %%
depth = '40_200'
Depth = '40-200'

############################################################################
doxy_wAS = ds_WOA['doxy_wAS_' + depth]
doxy_eAS = ds_WOA['doxy_eAS_' + depth]
doxy_wBoB = ds_WOA['doxy_wBoB_' + depth]
doxy_eBoB = ds_WOA['doxy_eBoB_' + depth]

sla_wAS = ds_SLA['sla_wAS']
sla_eAS = ds_SLA['sla_eAS']
sla_wBoB = ds_SLA['sla_wBoB']
sla_eBoB = ds_SLA['sla_eBoB']

mon_wAS = ds_WOA['mon_wAS']
mon_eAS = ds_WOA['mon_eAS']
mon_wBoB = ds_WOA['mon_wBoB']
mon_eBoB = ds_WOA['mon_eBoB']

# seas_wAS = ds_WOA['seas_wAS']
# seas_eAS = ds_WOA['seas_eAS']
# seas_wBoB = ds_WOA['seas_wBoB']
# seas_eBoB = ds_WOA['seas_eBoB']

doxy_wAS_ia = ds_WOD['doxy_wAS_' + depth]
doxy_eAS_ia = ds_WOD['doxy_eAS_' + depth]
doxy_wBoB_ia = ds_WOD['doxy_wBoB_' + depth]
doxy_eBoB_ia = ds_WOD['doxy_eBoB_' + depth]

sla_wAS_ia = ds_SLA_ia['sla_wAS']
sla_eAS_ia = ds_SLA_ia['sla_eAS']
sla_wBoB_ia = ds_SLA_ia['sla_wBoB']
sla_eBoB_ia = ds_SLA_ia['sla_eBoB']

mon_wAS_ia = ds_WOD['mon_wAS']
mon_eAS_ia = ds_WOD['mon_eAS']
mon_wBoB_ia = ds_WOD['mon_wBoB']
mon_eBoB_ia = ds_WOD['mon_eBoB']

seas_wAS_ia = ds_WOD['seas_wAS']
seas_eAS_ia = ds_WOD['seas_eAS']
seas_wBoB_ia = ds_WOD['seas_wBoB']
seas_eBoB_ia = ds_WOD['seas_eBoB']

##############################################################
fig = plt.figure(figsize=(17.8 / 2.54,3.5),dpi=400)

sz = 3
fsz = 6
lfz = 7
lw = 2
alpha = 1


xlim = [-0.3,0.3]
ylim = [-20,300]

cmap = get_continuous_cmap(['#034f84','#92a8d1','#b7d7e8','#f0f0f0','#f7cac9','#f7786b','#c94c4c'])

sp_clr = 'darkgreen'
sat_clr = 'lightgrey'

params = {'legend.fontsize': 8,
         'axes.labelsize': 8,
         'axes.titlesize': 10,
         'xtick.labelsize':8,
         'ytick.labelsize':8}

pylab.rcParams.update(params)

##############################################################

ax = fig.add_subplot(241)
ind = np.isnan(sla_wAS) | np.isnan(doxy_wAS)
p = ax.scatter(sla_wAS[~ind],doxy_wAS[~ind],c = mon_wAS[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ = stats.linregress(sla_wAS[~ind],doxy_wAS[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wAS[~ind],doxy_wAS[~ind])
print(p_val,r)
ax.plot(sla_wAS[~ind], m*sla_wAS[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_title('WAS')
ax.set_ylabel('Seasonal \n[$O_2$] ($\mu mol/ kg$)')
# ax.set_xlabel('Seasonal SLA ($m$)')
add_letter(ax, 'a', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(242)
ind = np.isnan(sla_eAS) | np.isnan(doxy_eAS)
p = ax.scatter(sla_eAS[~ind],doxy_eAS[~ind],c = mon_eAS[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ = stats.linregress(sla_eAS[~ind],doxy_eAS[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eAS[~ind],doxy_eAS[~ind])
print(p_val,r)
ax.plot(sla_eAS[~ind], m*sla_eAS[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('EAS')
# ax.set_xlabel('Seasonal SLA ($m$)')
add_letter(ax, 'b', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)  

ax = fig.add_subplot(243)
ind = np.isnan(sla_wBoB) | np.isnan(doxy_wBoB)
p = ax.scatter(sla_wBoB[~ind],doxy_wBoB[~ind],c = mon_wBoB[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_wBoB[~ind],doxy_wBoB[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wBoB[~ind],doxy_wBoB[~ind])
print(p_val,r)
ax.plot(sla_wBoB[~ind], m*sla_wBoB[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('WBoB')
# ax.set_xlabel('Seasonal SLA ($m$)')
ax.tick_params(axis='x',labelbottom='off')
ax.tick_params(axis='y',labelbottom='off')
add_letter(ax, 'c', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)  

ax = fig.add_subplot(244)
ind = np.isnan(sla_eBoB) | np.isnan(doxy_eBoB)
p = ax.scatter(sla_eBoB[~ind],doxy_eBoB[~ind],c = mon_eBoB[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eBoB[~ind],doxy_eBoB[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eBoB[~ind],doxy_eBoB[~ind])
print(p_val,r)
ax.plot(sla_eBoB[~ind], m*sla_eBoB[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('EBoB')
# ax.set_xlabel('Seasonal SLA ($m$)')
ax.tick_params(axis='x',labelbottom='off')
ax.tick_params(axis='y',labelbottom='off')
add_letter(ax, 'd', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

#-------------------------------------------------------------

ax = fig.add_subplot(245)
ind = np.isnan(sla_wAS_ia) | np.isnan(doxy_wAS_ia)
ax.scatter(sla_wAS_ia[~ind],doxy_wAS_ia[~ind],c = mon_wAS_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_wAS_ia[~ind], doxy_wAS_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wAS_ia[~ind],doxy_wAS_ia[~ind])
print(p_val,r)
ax.plot(sla_wAS_ia[~ind], m*sla_wAS_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_ylabel('Interannual \n[$O_2$] ($\mu mol/ kg$)')
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'e', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(246)
ind = np.isnan(sla_eAS_ia) | np.isnan(doxy_eAS_ia)
ax.scatter(sla_eAS_ia[~ind],doxy_eAS_ia[~ind],c = mon_eAS_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eAS_ia[~ind], doxy_eAS_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eAS_ia[~ind],doxy_eAS_ia[~ind])
print(p_val,r)
ax.plot(sla_eAS_ia[~ind], m*sla_eAS_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'f', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(247)
ind = np.isnan(sla_wBoB_ia) | np.isnan(doxy_wBoB_ia)
ax.scatter(sla_wBoB_ia[~ind],doxy_wBoB_ia[~ind],c = mon_wBoB_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
m, b, r, p_val,_ =stats.linregress(sla_wBoB_ia[~ind], doxy_wBoB_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wBoB_ia[~ind],doxy_wBoB_ia[~ind])
print(p_val,r)
ax.plot(sla_wBoB_ia[~ind], m*sla_wBoB_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'g', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(248)
ind = np.isnan(sla_eBoB_ia) | np.isnan(doxy_eBoB_ia)
ax.scatter(sla_eBoB_ia[~ind],doxy_eBoB_ia[~ind],c = mon_eBoB_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eBoB_ia[~ind], doxy_eBoB_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eBoB_ia[~ind],doxy_eBoB_ia[~ind])
print(p_val,r)
ax.plot(sla_eBoB_ia[~ind], m*sla_eBoB_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'h', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

mon_title = ['dec','jan','feb','mar','apr','may','jun','july','aug','sep','oct','nov']

cbar_ax = fig.add_axes([0.14, 0.12, 0.74, 0.03])
cbar = fig.colorbar(p,cax=cbar_ax, pad=0.04, orientation = 'horizontal', 
                         ticks = np.arange(1,13))
cbar.set_ticklabels(mon_title)
cbar.set_label('month')
cbar.ax.tick_params(labelsize = 7)

plt.subplots_adjust(hspace = 0.3, bottom = 0.3)

plt.savefig(figpath + 'corr_doxy_sla_' + depth + '.pdf', format='pdf', dpi = 400)
# Out:
# 1.0302015130535548e-26 0.6309024485812709
# 1.0302015130535977e-26 0.6309024485812708
# 1.8919016302393364e-101 0.5854512797438102
# 1.8919016302406844e-101 0.5854512797438105
# 8.138380624370687e-08 0.3994664483510372
# 8.138380624370633e-08 0.3994664483510373
# 2.7395830212662757e-24 0.30089978544586016
# 2.7395830212686833e-24 0.30089978544586016
# 2.193181175860607e-17 0.5266653530542389
# 2.1931811758605068e-17 0.5266653530542393
# 2.7885596268209417e-49 0.49177618378022714
# 2.7885596268201536e-49 0.49177618378022664
# 9.764969327582284e-18 0.7888844298938248
# 9.764969327582498e-18 0.7888844298938247
# 1.151947143074672e-21 0.5143909348501012
# 1.1519471430746823e-21 0.5143909348501012

# %% [markdown]
# # 50-225

# %%
depth = '50_225'
Depth = '50-225'

############################################################################
doxy_wAS = ds_WOA['doxy_wAS_' + depth]
doxy_eAS = ds_WOA['doxy_eAS_' + depth]
doxy_wBoB = ds_WOA['doxy_wBoB_' + depth]
doxy_eBoB = ds_WOA['doxy_eBoB_' + depth]

sla_wAS = ds_SLA['sla_wAS']
sla_eAS = ds_SLA['sla_eAS']
sla_wBoB = ds_SLA['sla_wBoB']
sla_eBoB = ds_SLA['sla_eBoB']

mon_wAS = ds_WOA['mon_wAS']
mon_eAS = ds_WOA['mon_eAS']
mon_wBoB = ds_WOA['mon_wBoB']
mon_eBoB = ds_WOA['mon_eBoB']

# seas_wAS = ds_WOA['seas_wAS']
# seas_eAS = ds_WOA['seas_eAS']
# seas_wBoB = ds_WOA['seas_wBoB']
# seas_eBoB = ds_WOA['seas_eBoB']

doxy_wAS_ia = ds_WOD['doxy_wAS_' + depth]
doxy_eAS_ia = ds_WOD['doxy_eAS_' + depth]
doxy_wBoB_ia = ds_WOD['doxy_wBoB_' + depth]
doxy_eBoB_ia = ds_WOD['doxy_eBoB_' + depth]

sla_wAS_ia = ds_SLA_ia['sla_wAS']
sla_eAS_ia = ds_SLA_ia['sla_eAS']
sla_wBoB_ia = ds_SLA_ia['sla_wBoB']
sla_eBoB_ia = ds_SLA_ia['sla_eBoB']

mon_wAS_ia = ds_WOD['mon_wAS']
mon_eAS_ia = ds_WOD['mon_eAS']
mon_wBoB_ia = ds_WOD['mon_wBoB']
mon_eBoB_ia = ds_WOD['mon_eBoB']

seas_wAS_ia = ds_WOD['seas_wAS']
seas_eAS_ia = ds_WOD['seas_eAS']
seas_wBoB_ia = ds_WOD['seas_wBoB']
seas_eBoB_ia = ds_WOD['seas_eBoB']

##############################################################
fig = plt.figure(figsize=(17.8 / 2.54,3.5),dpi=400)

sz = 3
fsz = 6
lfz = 7
lw = 2
alpha = 1


xlim = [-0.3,0.3]
ylim = [-20,300]

cmap = get_continuous_cmap(['#034f84','#92a8d1','#b7d7e8','#f0f0f0','#f7cac9','#f7786b','#c94c4c'])

sp_clr = 'darkgreen'
sat_clr = 'lightgrey'

params = {'legend.fontsize': 8,
         'axes.labelsize': 8,
         'axes.titlesize': 10,
         'xtick.labelsize':8,
         'ytick.labelsize':8}

pylab.rcParams.update(params)

##############################################################

ax = fig.add_subplot(241)
ind = np.isnan(sla_wAS) | np.isnan(doxy_wAS)
p = ax.scatter(sla_wAS[~ind],doxy_wAS[~ind],c = mon_wAS[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ = stats.linregress(sla_wAS[~ind],doxy_wAS[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wAS[~ind],doxy_wAS[~ind])
print(p_val,r)
ax.plot(sla_wAS[~ind], m*sla_wAS[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_title('WAS')
ax.set_ylabel('Seasonal \n[$O_2$] ($\mu mol/ kg$)')
# ax.set_xlabel('Seasonal SLA ($m$)')
add_letter(ax, 'a', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(242)
ind = np.isnan(sla_eAS) | np.isnan(doxy_eAS)
p = ax.scatter(sla_eAS[~ind],doxy_eAS[~ind],c = mon_eAS[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ = stats.linregress(sla_eAS[~ind],doxy_eAS[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eAS[~ind],doxy_eAS[~ind])
print(p_val,r)
ax.plot(sla_eAS[~ind], m*sla_eAS[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('EAS')
# ax.set_xlabel('Seasonal SLA ($m$)')
add_letter(ax, 'b', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)  

ax = fig.add_subplot(243)
ind = np.isnan(sla_wBoB) | np.isnan(doxy_wBoB)
p = ax.scatter(sla_wBoB[~ind],doxy_wBoB[~ind],c = mon_wBoB[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_wBoB[~ind],doxy_wBoB[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wBoB[~ind],doxy_wBoB[~ind])
print(p_val,r)
ax.plot(sla_wBoB[~ind], m*sla_wBoB[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('WBoB')
# ax.set_xlabel('Seasonal SLA ($m$)')
ax.tick_params(axis='x',labelbottom='off')
ax.tick_params(axis='y',labelbottom='off')
add_letter(ax, 'c', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)  

ax = fig.add_subplot(244)
ind = np.isnan(sla_eBoB) | np.isnan(doxy_eBoB)
p = ax.scatter(sla_eBoB[~ind],doxy_eBoB[~ind],c = mon_eBoB[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eBoB[~ind],doxy_eBoB[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eBoB[~ind],doxy_eBoB[~ind])
print(p_val,r)
ax.plot(sla_eBoB[~ind], m*sla_eBoB[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('EBoB')
# ax.set_xlabel('Seasonal SLA ($m$)')
ax.tick_params(axis='x',labelbottom='off')
ax.tick_params(axis='y',labelbottom='off')
add_letter(ax, 'd', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

#-------------------------------------------------------------

ax = fig.add_subplot(245)
ind = np.isnan(sla_wAS_ia) | np.isnan(doxy_wAS_ia)
ax.scatter(sla_wAS_ia[~ind],doxy_wAS_ia[~ind],c = mon_wAS_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_wAS_ia[~ind], doxy_wAS_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wAS_ia[~ind],doxy_wAS_ia[~ind])
print(p_val,r)
ax.plot(sla_wAS_ia[~ind], m*sla_wAS_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_ylabel('Interannual \n[$O_2$] ($\mu mol/ kg$)')
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'e', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(246)
ind = np.isnan(sla_eAS_ia) | np.isnan(doxy_eAS_ia)
ax.scatter(sla_eAS_ia[~ind],doxy_eAS_ia[~ind],c = mon_eAS_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eAS_ia[~ind], doxy_eAS_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eAS_ia[~ind],doxy_eAS_ia[~ind])
print(p_val,r)
ax.plot(sla_eAS_ia[~ind], m*sla_eAS_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'f', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(247)
ind = np.isnan(sla_wBoB_ia) | np.isnan(doxy_wBoB_ia)
ax.scatter(sla_wBoB_ia[~ind],doxy_wBoB_ia[~ind],c = mon_wBoB_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
m, b, r, p_val,_ =stats.linregress(sla_wBoB_ia[~ind], doxy_wBoB_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wBoB_ia[~ind],doxy_wBoB_ia[~ind])
print(p_val,r)
ax.plot(sla_wBoB_ia[~ind], m*sla_wBoB_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'g', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(248)
ind = np.isnan(sla_eBoB_ia) | np.isnan(doxy_eBoB_ia)
ax.scatter(sla_eBoB_ia[~ind],doxy_eBoB_ia[~ind],c = mon_eBoB_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eBoB_ia[~ind], doxy_eBoB_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eBoB_ia[~ind],doxy_eBoB_ia[~ind])
print(p_val,r)
ax.plot(sla_eBoB_ia[~ind], m*sla_eBoB_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'h', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

mon_title = ['dec','jan','feb','mar','apr','may','jun','july','aug','sep','oct','nov']

cbar_ax = fig.add_axes([0.14, 0.12, 0.74, 0.03])
cbar = fig.colorbar(p,cax=cbar_ax, pad=0.04, orientation = 'horizontal', 
                         ticks = np.arange(1,13))
cbar.set_ticklabels(mon_title)
cbar.set_label('month')
cbar.ax.tick_params(labelsize = 7)

plt.subplots_adjust(hspace = 0.3, bottom = 0.3)

plt.savefig(figpath + 'corr_doxy_sla_' + depth + '.pdf', format='pdf', dpi = 400)
# Out:
# 6.221127449241413e-25 0.613144067679439
# 6.221127449240922e-25 0.6131440676794394
# 1.2022718004415702e-91 0.5638200819780199
# 1.2022718004399747e-91 0.5638200819780198
# 6.566806844940345e-08 0.40209607032829237
# 6.566806844940365e-08 0.40209607032829237
# 2.15686632606095e-22 0.29014116216558666
# 2.156866326057919e-22 0.29014116216558683
# 1.6382464384167542e-21 0.6033079636392229
# 1.6382464384167293e-21 0.6033079636392233
# 2.0134816091515544e-45 0.47686033348885226
# 2.013481609152662e-45 0.4768603334888527
# 1.7830236417630032e-17 0.7850821190623826
# 1.783023641763021e-17 0.7850821190623826
# 2.1855062959730407e-20 0.5007937649189663
# 2.1855062959726317e-20 0.5007937649189665

# %% [markdown]
# # WOD18

# %%
# SLA
ds_SLA_ia = xr.open_dataset('../data/sla_to_wod18.nc')
# ds_SLA_ia

# %%
# AWG
ds_WOD = xr.open_dataset('../data/wod18_coastal_processed.nc')
ds_WOD
# Out:
# <xarray.Dataset>
# Dimensions:                (time_eAS: 22153, time_eBoB: 20613, time_wAS: 24246, time_wBoB: 2970)
# Coordinates:
#   * time_wAS               (time_wAS) datetime64[ns] 1905-12-15 ... 2018-12-23
#   * time_eAS               (time_eAS) datetime64[ns] 1770-01-01 ... 2018-12-30
#   * time_wBoB              (time_wBoB) datetime64[ns] 1827-10-10 ... 2018-12-11
#   * time_eBoB              (time_eBoB) datetime64[ns] 1770-01-01 ... 2018-12-31
# Data variables:
#     lat_wAS                (time_wAS) float32 ...
#     lon_wAS                (time_wAS) float32 ...
#     mon_wAS                (time_wAS) int64 ...
#     seas_wAS               (time_wAS) int64 ...
#     lat_eAS                (time_eAS) float32 ...
#     lon_eAS                (time_eAS) float32 ...
#     mon_eAS                (time_eAS) int64 ...
#     seas_eAS               (time_eAS) int64 ...
#     lat_wBoB               (time_wBoB) float32 ...
#     lon_wBoB               (time_wBoB) float32 ...
#     mon_wBoB               (time_wBoB) int64 ...
#     seas_wBoB              (time_wBoB) int64 ...
#     lat_eBoB               (time_eBoB) float32 ...
#     lon_eBoB               (time_eBoB) float32 ...
#     mon_eBoB               (time_eBoB) int64 ...
#     seas_eBoB              (time_eBoB) int64 ...
#     temp_wAS_50_200        (time_wAS) float64 ...
#     sal_wAS_50_200         (time_wAS) float64 ...
#     doxy_wAS_50_200        (time_wAS) float64 ...
#     nitrate_wAS_50_200     (time_wAS) float64 ...
#     phosphate_wAS_50_200   (time_wAS) float64 ...
#     O2_sat_wAS_50_200      (time_wAS) float64 ...
#     temp_eAS_50_200        (time_eAS) float64 ...
#     sal_eAS_50_200         (time_eAS) float64 ...
#     doxy_eAS_50_200        (time_eAS) float64 ...
#     nitrate_eAS_50_200     (time_eAS) float64 ...
#     phosphate_eAS_50_200   (time_eAS) float64 ...
#     O2_sat_eAS_50_200      (time_eAS) float64 ...
#     temp_wBoB_50_200       (time_wBoB) float64 ...
#     tsal_wBoB_50_200       (time_wBoB) float64 ...
#     doxy_wBoB_50_200       (time_wBoB) float64 ...
#     nitrate_wBoB_50_200    (time_wBoB) float64 ...
#     phosphate_wBoB_50_200  (time_wBoB) float64 ...
#     O2_sat_wBoB_50_200     (time_wBoB) float64 ...
#     temp_eBoB_50_200       (time_eBoB) float64 ...
#     sal_eBoB_50_200        (time_eBoB) float64 ...
#     doxy_eBoB_50_200       (time_eBoB) float64 ...
#     nitrate_eBoB_50_200    (time_eBoB) float64 ...
#     phosphate_eBoB_50_200  (time_eBoB) float64 ...
#     O2_sat_eBoB_50_200     (time_eBoB) float64 ...
#     temp_wAS_40_200        (time_wAS) float64 ...
#     sal_wAS_40_200         (time_wAS) float64 ...
#     doxy_wAS_40_200        (time_wAS) float64 ...
#     nitrate_wAS_40_200     (time_wAS) float64 ...
#     phosphate_wAS_40_200   (time_wAS) float64 ...
#     O2_sat_wAS_40_200      (time_wAS) float64 ...
#     temp_eAS_40_200        (time_eAS) float64 ...
#     sal_eAS_40_200         (time_eAS) float64 ...
#     doxy_eAS_40_200        (time_eAS) float64 ...
#     nitrate_eAS_40_200     (time_eAS) float64 ...
#     phosphate_eAS_40_200   (time_eAS) float64 ...
#     O2_sat_eAS_40_200      (time_eAS) float64 ...
#     temp_wBoB_40_200       (time_wBoB) float64 ...
#     tsal_wBoB_40_200       (time_wBoB) float64 ...
#     doxy_wBoB_40_200       (time_wBoB) float64 ...
#     nitrate_wBoB_40_200    (time_wBoB) float64 ...
#     phosphate_wBoB_40_200  (time_wBoB) float64 ...
#     O2_sat_wBoB_40_200     (time_wBoB) float64 ...
#     temp_eBoB_40_200       (time_eBoB) float64 ...
#     sal_eBoB_40_200        (time_eBoB) float64 ...
#     doxy_eBoB_40_200       (time_eBoB) float64 ...
#     nitrate_eBoB_40_200    (time_eBoB) float64 ...
#     phosphate_eBoB_40_200  (time_eBoB) float64 ...
#     O2_sat_eBoB_40_200     (time_eBoB) float64 ...
#     temp_wAS_50_225        (time_wAS) float64 ...
#     sal_wAS_50_225         (time_wAS) float64 ...
#     doxy_wAS_50_225        (time_wAS) float64 ...
#     nitrate_wAS_50_225     (time_wAS) float64 ...
#     phosphate_wAS_50_225   (time_wAS) float64 ...
#     O2_sat_wAS_50_225      (time_wAS) float64 ...
#     temp_eAS_50_225        (time_eAS) float64 ...
#     sal_eAS_50_225         (time_eAS) float64 ...
#     doxy_eAS_50_225        (time_eAS) float64 ...
#     nitrate_eAS_50_225     (time_eAS) float64 ...
#     phosphate_eAS_50_225   (time_eAS) float64 ...
#     O2_sat_eAS_50_225      (time_eAS) float64 ...
#     temp_wBoB_50_225       (time_wBoB) float64 ...
#     tsal_wBoB_50_225       (time_wBoB) float64 ...
#     doxy_wBoB_50_225       (time_wBoB) float64 ...
#     nitrate_wBoB_50_225    (time_wBoB) float64 ...
#     phosphate_wBoB_50_225  (time_wBoB) float64 ...
#     O2_sat_wBoB_50_225     (time_wBoB) float64 ...
#     temp_eBoB_50_225       (time_eBoB) float64 ...
#     sal_eBoB_50_225        (time_eBoB) float64 ...
#     doxy_eBoB_50_225       (time_eBoB) float64 ...
#     nitrate_eBoB_50_225    (time_eBoB) float64 ...
#     phosphate_eBoB_50_225  (time_eBoB) float64 ...
#     O2_sat_eBoB_50_225     (time_eBoB) float64 ...

# %%
depth = '50_200'
Depth = '50-200'

############################################################################
doxy_wAS = ds_WOA['doxy_wAS_' + depth]
doxy_eAS = ds_WOA['doxy_eAS_' + depth]
doxy_wBoB = ds_WOA['doxy_wBoB_' + depth]
doxy_eBoB = ds_WOA['doxy_eBoB_' + depth]

sla_wAS = ds_SLA['sla_wAS']
sla_eAS = ds_SLA['sla_eAS']
sla_wBoB = ds_SLA['sla_wBoB']
sla_eBoB = ds_SLA['sla_eBoB']

mon_wAS = ds_WOA['mon_wAS']
mon_eAS = ds_WOA['mon_eAS']
mon_wBoB = ds_WOA['mon_wBoB']
mon_eBoB = ds_WOA['mon_eBoB']

# seas_wAS = ds_WOA['seas_wAS']
# seas_eAS = ds_WOA['seas_eAS']
# seas_wBoB = ds_WOA['seas_wBoB']
# seas_eBoB = ds_WOA['seas_eBoB']

doxy_wAS_ia = ds_WOD['doxy_wAS_' + depth]
doxy_eAS_ia = ds_WOD['doxy_eAS_' + depth]
doxy_wBoB_ia = ds_WOD['doxy_wBoB_' + depth]
doxy_eBoB_ia = ds_WOD['doxy_eBoB_' + depth]

sla_wAS_ia = ds_SLA_ia['sla_wAS']
sla_eAS_ia = ds_SLA_ia['sla_eAS']
sla_wBoB_ia = ds_SLA_ia['sla_wBoB']
sla_eBoB_ia = ds_SLA_ia['sla_eBoB']

mon_wAS_ia = ds_WOD['mon_wAS']
mon_eAS_ia = ds_WOD['mon_eAS']
mon_wBoB_ia = ds_WOD['mon_wBoB']
mon_eBoB_ia = ds_WOD['mon_eBoB']

seas_wAS_ia = ds_WOD['seas_wAS']
seas_eAS_ia = ds_WOD['seas_eAS']
seas_wBoB_ia = ds_WOD['seas_wBoB']
seas_eBoB_ia = ds_WOD['seas_eBoB']

##############################################################
fig = plt.figure(figsize=(17.8 / 2.54,3.5),dpi=400)

sz = 3
fsz = 6
lfz = 7
lw = 2
alpha = 1


xlim = [-0.3,0.3]
ylim = [-20,300]

cmap = get_continuous_cmap(['#034f84','#92a8d1','#b7d7e8','#f0f0f0','#f7cac9','#f7786b','#c94c4c'])

sp_clr = 'darkgreen'
sat_clr = 'lightgrey'

params = {'legend.fontsize': 8,
         'axes.labelsize': 8,
         'axes.titlesize': 10,
         'xtick.labelsize':8,
         'ytick.labelsize':8}

pylab.rcParams.update(params)

##############################################################

ax = fig.add_subplot(241)
ind = np.isnan(sla_wAS) | np.isnan(doxy_wAS)
p = ax.scatter(sla_wAS[~ind],doxy_wAS[~ind],c = mon_wAS[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ = stats.linregress(sla_wAS[~ind],doxy_wAS[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wAS[~ind],doxy_wAS[~ind])
print(p_val,r)
ax.plot(sla_wAS[~ind], m*sla_wAS[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_title('WAS')
ax.set_ylabel('Seasonal \n[$O_2$] ($\mu mol/ kg$)')
# ax.set_xlabel('Seasonal SLA ($m$)')
add_letter(ax, 'a', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(242)
ind = np.isnan(sla_eAS) | np.isnan(doxy_eAS)
p = ax.scatter(sla_eAS[~ind],doxy_eAS[~ind],c = mon_eAS[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ = stats.linregress(sla_eAS[~ind],doxy_eAS[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eAS[~ind],doxy_eAS[~ind])
print(p_val,r)
ax.plot(sla_eAS[~ind], m*sla_eAS[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('EAS')
# ax.set_xlabel('Seasonal SLA ($m$)')
add_letter(ax, 'b', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)  

ax = fig.add_subplot(243)
ind = np.isnan(sla_wBoB) | np.isnan(doxy_wBoB)
p = ax.scatter(sla_wBoB[~ind],doxy_wBoB[~ind],c = mon_wBoB[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_wBoB[~ind],doxy_wBoB[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wBoB[~ind],doxy_wBoB[~ind])
print(p_val,r)
ax.plot(sla_wBoB[~ind], m*sla_wBoB[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('WBoB')
# ax.set_xlabel('Seasonal SLA ($m$)')
ax.tick_params(axis='x',labelbottom='off')
ax.tick_params(axis='y',labelbottom='off')
add_letter(ax, 'c', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)  

ax = fig.add_subplot(244)
ind = np.isnan(sla_eBoB) | np.isnan(doxy_eBoB)
p = ax.scatter(sla_eBoB[~ind],doxy_eBoB[~ind],c = mon_eBoB[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eBoB[~ind],doxy_eBoB[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eBoB[~ind],doxy_eBoB[~ind])
print(p_val,r)
ax.plot(sla_eBoB[~ind], m*sla_eBoB[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_title('EBoB')
# ax.set_xlabel('Seasonal SLA ($m$)')
ax.tick_params(axis='x',labelbottom='off')
ax.tick_params(axis='y',labelbottom='off')
add_letter(ax, 'd', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

#-------------------------------------------------------------

ax = fig.add_subplot(245)
ind = np.isnan(sla_wAS_ia) | np.isnan(doxy_wAS_ia)
ax.scatter(sla_wAS_ia[~ind],doxy_wAS_ia[~ind],c = mon_wAS_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_wAS_ia[~ind], doxy_wAS_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wAS_ia[~ind],doxy_wAS_ia[~ind])
print(p_val,r)
ax.plot(sla_wAS_ia[~ind], m*sla_wAS_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_ylabel('Interannual \n[$O_2$] ($\mu mol/ kg$)')
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'e', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(246)
ind = np.isnan(sla_eAS_ia) | np.isnan(doxy_eAS_ia)
ax.scatter(sla_eAS_ia[~ind],doxy_eAS_ia[~ind],c = mon_eAS_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eAS_ia[~ind], doxy_eAS_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eAS_ia[~ind],doxy_eAS_ia[~ind])
print(p_val,r)
ax.plot(sla_eAS_ia[~ind], m*sla_eAS_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'f', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(247)
ind = np.isnan(sla_wBoB_ia) | np.isnan(doxy_wBoB_ia)
ax.scatter(sla_wBoB_ia[~ind],doxy_wBoB_ia[~ind],c = mon_wBoB_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
m, b, r, p_val,_ =stats.linregress(sla_wBoB_ia[~ind], doxy_wBoB_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_wBoB_ia[~ind],doxy_wBoB_ia[~ind])
print(p_val,r)
ax.plot(sla_wBoB_ia[~ind], m*sla_wBoB_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'g', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

ax = fig.add_subplot(248)
ind = np.isnan(sla_eBoB_ia) | np.isnan(doxy_eBoB_ia)
ax.scatter(sla_eBoB_ia[~ind],doxy_eBoB_ia[~ind],c = mon_eBoB_ia[~ind],cmap = cmap,
               s= sz,alpha = alpha, edgecolor = 'none')
# ax.axvline(x=0,color = 'gray',linestyle = '--', linewidth = 0.5)
m, b, r, p_val,_ =stats.linregress(sla_eBoB_ia[~ind], doxy_eBoB_ia[~ind])
print(p_val,r)
r,p_val = stats.pearsonr(sla_eBoB_ia[~ind],doxy_eBoB_ia[~ind])
print(p_val,r)
ax.plot(sla_eBoB_ia[~ind], m*sla_eBoB_ia[~ind] + b, 'k', linewidth = lw)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_yticks([0,125,250])
ax.set_yticklabels([])
ax.set_xlabel('Sea-level Anomaly ($m$)')
add_letter(ax, 'h', x = 0.01,y=0.9, fontsize = lfz)
add_text(ax, 'y = ' + str(np.round(m,2)) + 'x-' + str(np.round(np.abs(b),2)), x = 0.1,y=0.91, fontsize = fsz)
add_text(ax, 'corr coeff: ' + str(np.round(r,2)), x = 0.1,y=0.8, fontsize = fsz)
add_text(ax, 'p-val: ' + r'${0:s}$'.format(as_si(p_val,2)), x = 0.1,y=0.7, fontsize = fsz-0.5)

mon_title = ['dec','jan','feb','mar','apr','may','jun','july','aug','sep','oct','nov']

cbar_ax = fig.add_axes([0.14, 0.12, 0.74, 0.03])
cbar = fig.colorbar(p,cax=cbar_ax, pad=0.04, orientation = 'horizontal', 
                         ticks = np.arange(1,13))
cbar.set_ticklabels(mon_title)
cbar.set_label('month')
cbar.ax.tick_params(labelsize = 7)

plt.subplots_adjust(hspace = 0.3, bottom = 0.3)

plt.savefig(figpath + 'corr_doxy_sla_wod18_' + depth + '.pdf', format='pdf', dpi = 400)
# Out:
# 6.644335080011249e-25 0.6128496343925349
# 6.6443350800109985e-25 0.6128496343925351
# 4.15268336219467e-98 0.580025663638337
# 4.152683362190858e-98 0.5800256636383365
# 7.105299376883388e-08 0.4011328010277671
# 7.105299376883404e-08 0.40113280102776705
# 6.275992275380213e-24 0.3001929261004623
# 6.275992275372038e-24 0.3001929261004624
# 3.2716883121678515e-22 0.6127636004561622
# 3.2716883121679197e-22 0.6127636004561623
# 1.6680741555947172e-45 0.5208035807070345
# 1.6680741555944916e-45 0.5208035807070353
# 1.2729079439011074e-17 0.7872198979765879
# 1.2729079439010154e-17 0.7872198979765883
# 4.740409423709913e-23 0.5299444119773802
# 4.740409423708784e-23 0.5299444119773804
